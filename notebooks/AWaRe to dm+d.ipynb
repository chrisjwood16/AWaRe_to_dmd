# %% [markdown]
# ### UK Access, Watch, Reserve, and Other classification for antibiotics in dmd

# %% [markdown]
# The ["UK Access, Watch, Reserve, and Other classification for antibiotics"](https://www.gov.uk/government/publications/uk-aware-antibiotic-classification/uk-access-watch-reserve-and-other-classification-for-antibiotics-uk-aware-antibiotic-classification) categorises antibiotics into groups such as Access, Watch, and Reserve to guide healthcare professionals in optimising their use and mitigating antimicrobial resistance.
#
# To facilitate research, it is helpful to link this categorisation to the [dm+d standard](https://www.nhsbsa.nhs.uk/pharmacies-gp-practices-and-appliance-contractors/dictionary-medicines-and-devices-dmd).

# %% [markdown]
# ### Imports
# We need to import some libaries to help with the code

# %%
import pandas as pd
import requests
from ebmdatalab import bq
import os

# %% [markdown]
# ### Getting the AWaRe list
# The AWaRe list is currently available on the following webpage. We can read the html page directly into Pandas to retrieve the first table.

# %%
# Set URL to scrape
url = "https://www.gov.uk/government/publications/uk-aware-antibiotic-classification/uk-access-watch-reserve-and-other-classification-for-antibiotics-uk-aware-antibiotic-classification"

# Read the first HTML table from the page into a DataFrame using the HTML content
df = pd.read_html(url)[0]

# Display the DataFrame
df
# Out:
#                       Antibiotic England-adapted 2019 AWaRe category  \
# 0                       Amikacin                               Watch
# 1                    Amoxicillin                              Access
# 2   Amoxicillin/ clavulanic-acid                               Watch
# 3                     Ampicillin                              Access
# 4                   Azithromycin                               Watch
# ..                           ...                                 ...
# 85                   Tigecycline                             Reserve
# 86                  Tinidazole #                               Other
# 87                    Tobramycin                               Watch
# 88                  Trimethoprim                              Access
# 89                    Vancomycin                               Watch
#
#    UK-adapted 2024 AWaRe category
# 0                           Watch
# 1                          Access
# 2                           Watch
# 3                          Access
# 4                           Watch
# ..                            ...
# 85                        Reserve
# 86                         Access
# 87                          Watch
# 88                         Access
# 89                          Watch
#
# [90 rows x 3 columns]

# %% [markdown]
# ### Cleaning up the list
# The list contains some characters or identifiers that could break matching, we need to clean these up.

# %% [markdown]
# The # symbol is used to denote where category has changed, remove this

# %%
df['Antibiotic'] = df['Antibiotic'].str.replace(" #", "", regex=False)

# %% [markdown]
# We can review remaining rows that contain non-alphabetical characters

# %%
df[df['Antibiotic'].str.contains(r'[^A-Za-z ]', na=False)]
# Out:
#                         Antibiotic England-adapted 2019 AWaRe category  \
# 2     Amoxicillin/ clavulanic-acid                               Watch
# 6      Benzathine-benzylpenicillin                              Access
# 20             Ceftaroline-fosamil                             Reserve
# 22          Ceftazidime/ avibactam                             Reserve
# 23          Ceftobiprole-medocaril                             Reserve
# 24         Ceftolozane/ tazobactam                             Reserve
# 31           Colistin, intravenous                             Reserve
# 32                  Colistin, oral                             Reserve
# 34      Dalfopristin/ quinupristin                             Reserve
# 46         Fosfomycin, intravenous                             Reserve
# 49             Imipenem/cilastatin                             Reserve
# 50  Imipenem/cilastatin/relebactam                             Reserve
# 55          Meropenem/ vaborbactam                             Reserve
# 69         Piperacillin/tazobactam                               Watch
# 72       Procaine-benzylpenicillin                              Access
# 75       Streptomycin, intravenous                               Other
# 77  Sulfamethoxazole/ trimethoprim                              Access
#
#    UK-adapted 2024 AWaRe category
# 2                           Watch
# 6                          Access
# 20                        Reserve
# 22                        Reserve
# 23                        Reserve
# 24                        Reserve
# 31                        Reserve
# 32                        Reserve
# 34                        Reserve
# 46                        Reserve
# 49                        Reserve
# 50                        Reserve
# 55                        Reserve
# 69                          Watch
# 72                         Access
# 75                          Other
# 77                         Access

# %% [markdown]
# Some rows specify a route. Sometimes there is a comma between antibiotic and route, sometimes there isn't. We can pull any specified route into a seperate column.

# %%
# List of routes to check.
route_list = ["oral", "intravenous"]

# Function to extract the route if the Antibiotic entry ends with a route.
def extract_route(antibiotic):
    for route in route_list:
        if antibiotic.endswith(" " + route):
            return route
    return ""  # Return empty string if no route is found.

# Apply the function to create a new 'Route' column.
df['Route'] = df['Antibiotic'].apply(extract_route)

# Remove any route names from the 'Antibiotic' column only if they appear at the end
# and are preceded by either ", " or " ".
for route in route_list:
    df['Antibiotic'] = df['Antibiotic'].str.replace(fr'(, | ){route}$', '', regex=True)

# %%
df[df['Antibiotic'].str.contains(r'[^A-Za-z ]', na=False)]
# Out:
#                         Antibiotic England-adapted 2019 AWaRe category  \
# 2     Amoxicillin/ clavulanic-acid                               Watch
# 6      Benzathine-benzylpenicillin                              Access
# 20             Ceftaroline-fosamil                             Reserve
# 22          Ceftazidime/ avibactam                             Reserve
# 23          Ceftobiprole-medocaril                             Reserve
# 24         Ceftolozane/ tazobactam                             Reserve
# 34      Dalfopristin/ quinupristin                             Reserve
# 49             Imipenem/cilastatin                             Reserve
# 50  Imipenem/cilastatin/relebactam                             Reserve
# 55          Meropenem/ vaborbactam                             Reserve
# 69         Piperacillin/tazobactam                               Watch
# 72       Procaine-benzylpenicillin                              Access
# 77  Sulfamethoxazole/ trimethoprim                              Access
#
#    UK-adapted 2024 AWaRe category Route
# 2                           Watch
# 6                          Access
# 20                        Reserve
# 22                        Reserve
# 23                        Reserve
# 24                        Reserve
# 34                        Reserve
# 49                        Reserve
# 50                        Reserve
# 55                        Reserve
# 69                          Watch
# 72                         Access
# 77                         Access

# %% [markdown]
# Some items contain a dash between words where as in dm+d there is a space. Replace the dash with a space to follow the common format.

# %%
df['Antibiotic'] = df['Antibiotic'].str.replace("-", " ", regex=False)

# %% [markdown]
# Some items contain a forward slash between words to indicate a combination where as in dm+d there is a + symbol. Replace the dash with a + ensuring appropriately spaced to follow the common dm+d format.

# %%
# Replace / with a + ensuring it is appropriately spaced and 2nd drug name is capitalised
df['Antibiotic'] = (
    df['Antibiotic']
    .str.replace(r'\s*/\s*', ' + ', regex=True)
    .str.replace(r'(\+\s+)(\w)', lambda m: m.group(1) + m.group(2).upper(), regex=True)
)
# Create a new column 'Combo' that is True if 'Antibiotic' contains a plus between two words.
df['Combo'] = df['Antibiotic'].str.contains(r'\b\w+\s*\+\s*\w+\b', regex=True)

# %%
df[df['Antibiotic'].str.contains(r'[^A-Za-z ]', na=False)]
# Out:
#                             Antibiotic England-adapted 2019 AWaRe category  \
# 2        Amoxicillin + Clavulanic acid                               Watch
# 22             Ceftazidime + Avibactam                             Reserve
# 24            Ceftolozane + Tazobactam                             Reserve
# 34         Dalfopristin + Quinupristin                             Reserve
# 49               Imipenem + Cilastatin                             Reserve
# 50  Imipenem + Cilastatin + Relebactam                             Reserve
# 55             Meropenem + Vaborbactam                             Reserve
# 69           Piperacillin + Tazobactam                               Watch
# 77     Sulfamethoxazole + Trimethoprim                              Access
#
#    UK-adapted 2024 AWaRe category Route  Combo
# 2                           Watch         True
# 22                        Reserve         True
# 24                        Reserve         True
# 34                        Reserve         True
# 49                        Reserve         True
# 50                        Reserve         True
# 55                        Reserve         True
# 69                          Watch         True
# 77                         Access         True

# %% [markdown]
# Some antibiotic combinations are referred to as different names or in a different order in dm+d. Convert to use these. (Found these issues via dm+d manual search)

# %%
df['Antibiotic'] = df['Antibiotic'].str.replace("Amoxicillin + Clavulanic acid", "Co-amoxiclav", regex=False)
df['Antibiotic'] = df['Antibiotic'].str.replace("Sulfamethoxazole + Trimethoprim", "Co-trimoxazole", regex=False)
df['Antibiotic'] = df['Antibiotic'].str.replace("Dalfopristin + Quinupristin", "Quinupristin + Dalfopristin", regex=False)
df['Antibiotic'] = df['Antibiotic'].str.replace("Imipenem + Cilastatin + Relebactam", "Cilastatin + Imipenem + Relebactam", regex=False)
df['Antibiotic'] = df['Antibiotic'].str.replace("Ceftobiprole medocaril", "Ceftobiprole", regex=False)

# %% [markdown]
# Reorder the columns

# %%
df = df[['Antibiotic', 'Route', 'Combo'] + [col for col in df.columns if col not in ['Antibiotic', 'Route', 'Combo']]]

# %%
with pd.option_context('display.max_rows', None):
    display(df)
# Out:
#                             Antibiotic        Route  Combo  \
# 0                             Amikacin               False
# 1                          Amoxicillin               False
# 2                         Co-amoxiclav                True
# 3                           Ampicillin               False
# 4                         Azithromycin               False
# 5                            Aztreonam               False
# 6          Benzathine benzylpenicillin               False
# 7                     Benzylpenicillin               False
# 8                             Cefaclor               False
# 9                           Cefadroxil               False
# 10                           Cefalexin               False
# 11                           Cefalotin               False
# 12                         Cefamandole               False
# 13                           Cefazolin               False
# 14                            Cefepime               False
# 15                         Cefiderocol               False
# 16                            Cefixime               False
# 17                          Cefotaxime               False
# 18                           Cefoxitin               False
# 19                           Cefradine               False
# 20                 Ceftaroline fosamil               False
# 21                         Ceftazidime               False
# 22             Ceftazidime + Avibactam                True
# 23                        Ceftobiprole               False
# 24            Ceftolozane + Tazobactam                True
# 25                         Ceftriaxone               False
# 26                          Cefuroxime               False
# 27                     Chloramphenicol               False
# 28                       Ciprofloxacin               False
# 29                      Clarithromycin               False
# 30                         Clindamycin               False
# 31                            Colistin  intravenous  False
# 32                            Colistin         oral  False
# 33                         Dalbavancin               False
# 34         Quinupristin + Dalfopristin                True
# 35                          Daptomycin               False
# 36                        Delafloxacin               False
# 37                      Demeclocycline               False
# 38                           Doripenem               False
# 39                         Doxycycline               False
# 40                        Eravacycline               False
# 41                           Ertapenem               False
# 42                        Erythromycin               False
# 43                         Fidaxomicin               False
# 44                      Flucloxacillin               False
# 45                          Fosfomycin         oral  False
# 46                          Fosfomycin  intravenous  False
# 47                        Fusidic acid               False
# 48                          Gentamicin               False
# 49               Imipenem + Cilastatin                True
# 50  Cilastatin + Imipenem + Relebactam                True
# 51                        Levofloxacin               False
# 52                           Linezolid               False
# 53                         Lymecycline               False
# 54                           Meropenem               False
# 55             Meropenem + Vaborbactam                True
# 56                         Methenamine               False
# 57                       Metronidazole               False
# 58                         Minocycline         oral  False
# 59                        Moxifloxacin               False
# 60                      Nalidixic Acid               False
# 61                            Neomycin               False
# 62                      Nitrofurantoin               False
# 63                         Norfloxacin               False
# 64                           Ofloxacin               False
# 65                         Oritavancin               False
# 66                     Oxytetracycline               False
# 67             Phenoxymethylpenicillin               False
# 68                        Piperacillin               False
# 69           Piperacillin + Tazobactam                True
# 70                       Pivmecillinam               False
# 71                       Pristinamycin               False
# 72           Procaine benzylpenicillin               False
# 73                       Spectinomycin               False
# 74                          Spiramycin               False
# 75                        Streptomycin  intravenous  False
# 76                        Sulfadiazine               False
# 77                      Co-trimoxazole                True
# 78              Sulfamethoxypyridazine               False
# 79                       Sulfapyridine               False
# 80                           Tedizolid               False
# 81                         Teicoplanin               False
# 82                          Telavancin               False
# 83                          Temocillin               False
# 84                        Tetracycline               False
# 85                         Tigecycline               False
# 86                          Tinidazole               False
# 87                          Tobramycin               False
# 88                        Trimethoprim               False
# 89                          Vancomycin               False
#
#    England-adapted 2019 AWaRe category UK-adapted 2024 AWaRe category
# 0                                Watch                          Watch
# 1                               Access                         Access
# 2                                Watch                          Watch
# 3                               Access                         Access
# 4                                Watch                          Watch
# 5                              Reserve                        Reserve
# 6                               Access                         Access
# 7                               Access                         Access
# 8                                Watch                          Watch
# 9                                Watch                         Access
# 10                               Watch                         Access
# 11                               Watch                         Access
# 12                               Watch                          Watch
# 13                               Watch                         Access
# 14                               Watch                          Watch
# 15                             Reserve                        Reserve
# 16                               Watch                          Watch
# 17                               Watch                          Watch
# 18                               Watch                          Watch
# 19                               Watch                         Access
# 20                             Reserve                        Reserve
# 21                               Watch                          Watch
# 22                             Reserve                        Reserve
# 23                             Reserve                        Reserve
# 24                             Reserve                        Reserve
# 25                               Watch                          Watch
# 26                               Watch                          Watch
# 27                               Watch                          Watch
# 28                               Watch                          Watch
# 29                               Watch                          Watch
# 30                               Watch                          Watch
# 31                             Reserve                        Reserve
# 32                             Reserve                        Reserve
# 33                             Reserve                        Reserve
# 34                             Reserve                        Reserve
# 35                             Reserve                        Reserve
# 36                               Watch                          Watch
# 37                               Watch                          Other
# 38                             Reserve                        Reserve
# 39                              Access                         Access
# 40                             Reserve                        Reserve
# 41                             Reserve                        Reserve
# 42                               Watch                          Watch
# 43                               Watch                          Watch
# 44                              Access                         Access
# 45                              Access                         Access
# 46                             Reserve                        Reserve
# 47                              Access                          Watch
# 48                              Access                         Access
# 49                             Reserve                        Reserve
# 50                             Reserve                        Reserve
# 51                               Watch                          Watch
# 52                             Reserve                        Reserve
# 53                               Watch                          Watch
# 54                             Reserve                        Reserve
# 55                             Reserve                        Reserve
# 56                               Other                          Other
# 57                              Access                         Access
# 58                               Watch                          Watch
# 59                               Watch                          Watch
# 60                               Other                          Other
# 61                               Watch                          Watch
# 62                              Access                         Access
# 63                               Watch                          Watch
# 64                               Watch                          Watch
# 65                             Reserve                        Reserve
# 66                               Watch                          Watch
# 67                              Access                         Access
# 68                               Watch                          Watch
# 69                               Watch                          Watch
# 70                              Access                         Access
# 71                               Watch                          Other
# 72                              Access                         Access
# 73                               Other                          Other
# 74                               Other                          Other
# 75                               Other                          Other
# 76                               Other                          Other
# 77                              Access                         Access
# 78                               Other                          Other
# 79                               Other                          Other
# 80                             Reserve                        Reserve
# 81                               Watch                          Watch
# 82                             Reserve                        Reserve
# 83                               Watch                          Watch
# 84                              Access                         Access
# 85                             Reserve                        Reserve
# 86                               Other                         Access
# 87                               Watch                          Watch
# 88                              Access                         Access
# 89                               Watch                          Watch

# %% [markdown]
# ### Matching to dm+d
# Firstly try to match the antibiotic to a VTM

# %%
# Get a list of unique antibiotic values from your DataFrame.
list_of_abx = df['Antibiotic'].str.lower().unique().tolist()

# Convert the list into a comma-separated string of quoted values.
formatted_list = ", ".join(f"'{abx}'" for abx in list_of_abx)

# Construct the query using the formatted list.
sql = f"""
SELECT vtm.id, vtm.nm
FROM `ebmdatalab.dmd.vtm` vtm
WHERE lower(vtm.nm) IN ({formatted_list})
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vtm_match.csv')

# Use the cached_read function from the bq library to run the query.
vtms_df = bq.cached_read(sql, csv_path=csv_path)

# Rename vtms_df column 'id' to 'vtm_id'
vtms_df = vtms_df.rename(columns={'id': 'vtm_id'})

df = (
    df.assign(antibiotic_lower=df['Antibiotic'].str.lower())
      .merge(
          vtms_df.assign(nm_lower=vtms_df['nm'].str.lower()),
          left_on='antibiotic_lower',
          right_on='nm_lower',
          how='left'
      )
      .assign(vtm_id=lambda x: x['vtm_id'].fillna(0).astype('int64'))
      .drop(columns=['antibiotic_lower', 'nm_lower'])
)
df = df.rename(columns={'nm': 'vtm_nm'})

with pd.option_context('display.max_rows', None):
    display(df)
# Out:
#                             Antibiotic        Route  Combo  \
# 0                             Amikacin               False
# 1                          Amoxicillin               False
# 2                         Co-amoxiclav                True
# 3                           Ampicillin               False
# 4                         Azithromycin               False
# 5                            Aztreonam               False
# 6          Benzathine benzylpenicillin               False
# 7                     Benzylpenicillin               False
# 8                             Cefaclor               False
# 9                           Cefadroxil               False
# 10                           Cefalexin               False
# 11                           Cefalotin               False
# 12                         Cefamandole               False
# 13                           Cefazolin               False
# 14                            Cefepime               False
# 15                         Cefiderocol               False
# 16                            Cefixime               False
# 17                          Cefotaxime               False
# 18                           Cefoxitin               False
# 19                           Cefradine               False
# 20                 Ceftaroline fosamil               False
# 21                         Ceftazidime               False
# 22             Ceftazidime + Avibactam                True
# 23                        Ceftobiprole               False
# 24            Ceftolozane + Tazobactam                True
# 25                         Ceftriaxone               False
# 26                          Cefuroxime               False
# 27                     Chloramphenicol               False
# 28                       Ciprofloxacin               False
# 29                      Clarithromycin               False
# 30                         Clindamycin               False
# 31                            Colistin  intravenous  False
# 32                            Colistin         oral  False
# 33                         Dalbavancin               False
# 34         Quinupristin + Dalfopristin                True
# 35                          Daptomycin               False
# 36                        Delafloxacin               False
# 37                      Demeclocycline               False
# 38                           Doripenem               False
# 39                         Doxycycline               False
# 40                        Eravacycline               False
# 41                           Ertapenem               False
# 42                        Erythromycin               False
# 43                         Fidaxomicin               False
# 44                      Flucloxacillin               False
# 45                          Fosfomycin         oral  False
# 46                          Fosfomycin  intravenous  False
# 47                        Fusidic acid               False
# 48                          Gentamicin               False
# 49               Imipenem + Cilastatin                True
# 50  Cilastatin + Imipenem + Relebactam                True
# 51                        Levofloxacin               False
# 52                           Linezolid               False
# 53                         Lymecycline               False
# 54                           Meropenem               False
# 55             Meropenem + Vaborbactam                True
# 56                         Methenamine               False
# 57                       Metronidazole               False
# 58                         Minocycline         oral  False
# 59                        Moxifloxacin               False
# 60                      Nalidixic Acid               False
# 61                            Neomycin               False
# 62                      Nitrofurantoin               False
# 63                         Norfloxacin               False
# 64                           Ofloxacin               False
# 65                         Oritavancin               False
# 66                     Oxytetracycline               False
# 67             Phenoxymethylpenicillin               False
# 68                        Piperacillin               False
# 69           Piperacillin + Tazobactam                True
# 70                       Pivmecillinam               False
# 71                       Pristinamycin               False
# 72           Procaine benzylpenicillin               False
# 73                       Spectinomycin               False
# 74                          Spiramycin               False
# 75                        Streptomycin  intravenous  False
# 76                        Sulfadiazine               False
# 77                      Co-trimoxazole                True
# 78              Sulfamethoxypyridazine               False
# 79                       Sulfapyridine               False
# 80                           Tedizolid               False
# 81                         Teicoplanin               False
# 82                          Telavancin               False
# 83                          Temocillin               False
# 84                        Tetracycline               False
# 85                         Tigecycline               False
# 86                          Tinidazole               False
# 87                          Tobramycin               False
# 88                        Trimethoprim               False
# 89                          Vancomycin               False
#
#    England-adapted 2019 AWaRe category UK-adapted 2024 AWaRe category  \
# 0                                Watch                          Watch
# 1                               Access                         Access
# 2                                Watch                          Watch
# 3                               Access                         Access
# 4                                Watch                          Watch
# 5                              Reserve                        Reserve
# 6                               Access                         Access
# 7                               Access                         Access
# 8                                Watch                          Watch
# 9                                Watch                         Access
# 10                               Watch                         Access
# 11                               Watch                         Access
# 12                               Watch                          Watch
# 13                               Watch                         Access
# 14                               Watch                          Watch
# 15                             Reserve                        Reserve
# 16                               Watch                          Watch
# 17                               Watch                          Watch
# 18                               Watch                          Watch
# 19                               Watch                         Access
# 20                             Reserve                        Reserve
# 21                               Watch                          Watch
# 22                             Reserve                        Reserve
# 23                             Reserve                        Reserve
# 24                             Reserve                        Reserve
# 25                               Watch                          Watch
# 26                               Watch                          Watch
# 27                               Watch                          Watch
# 28                               Watch                          Watch
# 29                               Watch                          Watch
# 30                               Watch                          Watch
# 31                             Reserve                        Reserve
# 32                             Reserve                        Reserve
# 33                             Reserve                        Reserve
# 34                             Reserve                        Reserve
# 35                             Reserve                        Reserve
# 36                               Watch                          Watch
# 37                               Watch                          Other
# 38                             Reserve                        Reserve
# 39                              Access                         Access
# 40                             Reserve                        Reserve
# 41                             Reserve                        Reserve
# 42                               Watch                          Watch
# 43                               Watch                          Watch
# 44                              Access                         Access
# 45                              Access                         Access
# 46                             Reserve                        Reserve
# 47                              Access                          Watch
# 48                              Access                         Access
# 49                             Reserve                        Reserve
# 50                             Reserve                        Reserve
# 51                               Watch                          Watch
# 52                             Reserve                        Reserve
# 53                               Watch                          Watch
# 54                             Reserve                        Reserve
# 55                             Reserve                        Reserve
# 56                               Other                          Other
# 57                              Access                         Access
# 58                               Watch                          Watch
# 59                               Watch                          Watch
# 60                               Other                          Other
# 61                               Watch                          Watch
# 62                              Access                         Access
# 63                               Watch                          Watch
# 64                               Watch                          Watch
# 65                             Reserve                        Reserve
# 66                               Watch                          Watch
# 67                              Access                         Access
# 68                               Watch                          Watch
# 69                               Watch                          Watch
# 70                              Access                         Access
# 71                               Watch                          Other
# 72                              Access                         Access
# 73                               Other                          Other
# 74                               Other                          Other
# 75                               Other                          Other
# 76                               Other                          Other
# 77                              Access                         Access
# 78                               Other                          Other
# 79                               Other                          Other
# 80                             Reserve                        Reserve
# 81                               Watch                          Watch
# 82                             Reserve                        Reserve
# 83                               Watch                          Watch
# 84                              Access                         Access
# 85                             Reserve                        Reserve
# 86                               Other                         Access
# 87                               Watch                          Watch
# 88                              Access                         Access
# 89                               Watch                          Watch
#
#                vtm_id                              vtm_nm
# 0           774534000                            Amikacin
# 1           774586009                         Amoxicillin
# 2           774587000                        Co-amoxiclav
# 3           774590006                          Ampicillin
# 4           774722005                        Azithromycin
# 5           774725007                           Aztreonam
# 6          1234764000         Benzathine benzylpenicillin
# 7           774826003                    Benzylpenicillin
# 8           775086009                            Cefaclor
# 9           775087000                          Cefadroxil
# 10          775088005                           Cefalexin
# 11                  0                                 NaN
# 12          775090006                         Cefamandole
# 13          775092003                           Cefazolin
# 14          775095001                            Cefepime
# 15          830205006                         Cefiderocol
# 16          775097009                            Cefixime
# 17          775103002                          Cefotaxime
# 18          775107001                           Cefoxitin
# 19          775112000                           Cefradine
# 20  21387311000001104                 Ceftaroline fosamil
# 21          775115003                         Ceftazidime
# 22          781300005             Ceftazidime + Avibactam
# 23         1287090001                        Ceftobiprole
# 24          775119009            Ceftolozane + Tazobactam
# 25          775120003                         Ceftriaxone
# 26          775121004                          Cefuroxime
# 27          775160002                     Chloramphenicol
# 28          775261009                       Ciprofloxacin
# 29          775277005                      Clarithromycin
# 30          775288004                         Clindamycin
# 31          775373006                            Colistin
# 32          775373006                            Colistin
# 33          775437000                         Dalbavancin
# 34          775439002         Quinupristin + Dalfopristin
# 35          775451000                          Daptomycin
# 36          775469009                        Delafloxacin
# 37          775476004                      Demeclocycline
# 38          775689001                           Doripenem
# 39          775698003                         Doxycycline
# 40          775807004                        Eravacycline
# 41          775820001                           Ertapenem
# 42          775822009                        Erythromycin
# 43          775961002                         Fidaxomicin
# 44          775979003                      Flucloxacillin
# 45          776041001                          Fosfomycin
# 46          776041001                          Fosfomycin
# 47          776058006                        Fusidic acid
# 48          776094005                          Gentamicin
# 49          775245007               Imipenem + Cilastatin
# 50          789074009  Cilastatin + Imipenem + Relebactam
# 51          776517005                        Levofloxacin
# 52          776544000                           Linezolid
# 53          776593005                         Lymecycline
# 54          776694006                           Meropenem
# 55          776695007             Meropenem + Vaborbactam
# 56          776725009                         Methenamine
# 57          776774005                       Metronidazole
# 58          776800005                         Minocycline
# 59          776831003                        Moxifloxacin
# 60          776859002                      Nalidixic acid
# 61          776885003                            Neomycin
# 62          776927008                      Nitrofurantoin
# 63          776943001                         Norfloxacin
# 64          776973005                           Ofloxacin
# 65          777001001                         Oritavancin
# 66          777035003                     Oxytetracycline
# 67          777175009             Phenoxymethylpenicillin
# 68                  0                                 NaN
# 69          777212006           Piperacillin + Tazobactam
# 70          777227006                       Pivmecillinam
# 71  16251011000001104                       Pristinamycin
# 72         1234762001           Procaine benzylpenicillin
# 73          777600004                       Spectinomycin
# 74          777602007                          Spiramycin
# 75          777614004                        Streptomycin
# 76          777532008                        Sulfadiazine
# 77  18037511000001104                      Co-trimoxazole
# 78          777643007              Sulfamethoxypyridazine
# 79  15465811000001106                       Sulfapyridine
# 80          777686007                           Tedizolid
# 81          777691008                         Teicoplanin
# 82          777693006                          Telavancin
# 83          777700006                          Temocillin
# 84          777730003                        Tetracycline
# 85          777769009                         Tigecycline
# 86          777775000                          Tinidazole
# 87          777791002                          Tobramycin
# 88          777858001                        Trimethoprim
# 89          777914002                          Vancomycin

# %% [markdown]
# Show any rows where no VTM match has happened.

# %%
df[df['vtm_id'] == 0]
# Out:
#       Antibiotic Route  Combo England-adapted 2019 AWaRe category  \
# 11     Cefalotin        False                               Watch
# 68  Piperacillin        False                               Watch
#
#    UK-adapted 2024 AWaRe category  vtm_id vtm_nm
# 11                         Access       0    NaN
# 68                          Watch       0    NaN

# %% [markdown]
# After manual checking neither of these have an matching products in the UK currently so we can remove them.

# %%
df = df[df['vtm_id'] != 0]

# %% [markdown]
# Re-order the columns

# %%
df = df[['Antibiotic', 'Route', 'Combo', 'vtm_id'] + [col for col in df.columns if col not in ['Antibiotic', 'Route', 'Combo', 'vtm_id']]]

# %%
with pd.option_context('display.max_rows', None):
    display(df)
# Out:
#                             Antibiotic        Route  Combo             vtm_id  \
# 0                             Amikacin               False          774534000
# 1                          Amoxicillin               False          774586009
# 2                         Co-amoxiclav                True          774587000
# 3                           Ampicillin               False          774590006
# 4                         Azithromycin               False          774722005
# 5                            Aztreonam               False          774725007
# 6          Benzathine benzylpenicillin               False         1234764000
# 7                     Benzylpenicillin               False          774826003
# 8                             Cefaclor               False          775086009
# 9                           Cefadroxil               False          775087000
# 10                           Cefalexin               False          775088005
# 12                         Cefamandole               False          775090006
# 13                           Cefazolin               False          775092003
# 14                            Cefepime               False          775095001
# 15                         Cefiderocol               False          830205006
# 16                            Cefixime               False          775097009
# 17                          Cefotaxime               False          775103002
# 18                           Cefoxitin               False          775107001
# 19                           Cefradine               False          775112000
# 20                 Ceftaroline fosamil               False  21387311000001104
# 21                         Ceftazidime               False          775115003
# 22             Ceftazidime + Avibactam                True          781300005
# 23                        Ceftobiprole               False         1287090001
# 24            Ceftolozane + Tazobactam                True          775119009
# 25                         Ceftriaxone               False          775120003
# 26                          Cefuroxime               False          775121004
# 27                     Chloramphenicol               False          775160002
# 28                       Ciprofloxacin               False          775261009
# 29                      Clarithromycin               False          775277005
# 30                         Clindamycin               False          775288004
# 31                            Colistin  intravenous  False          775373006
# 32                            Colistin         oral  False          775373006
# 33                         Dalbavancin               False          775437000
# 34         Quinupristin + Dalfopristin                True          775439002
# 35                          Daptomycin               False          775451000
# 36                        Delafloxacin               False          775469009
# 37                      Demeclocycline               False          775476004
# 38                           Doripenem               False          775689001
# 39                         Doxycycline               False          775698003
# 40                        Eravacycline               False          775807004
# 41                           Ertapenem               False          775820001
# 42                        Erythromycin               False          775822009
# 43                         Fidaxomicin               False          775961002
# 44                      Flucloxacillin               False          775979003
# 45                          Fosfomycin         oral  False          776041001
# 46                          Fosfomycin  intravenous  False          776041001
# 47                        Fusidic acid               False          776058006
# 48                          Gentamicin               False          776094005
# 49               Imipenem + Cilastatin                True          775245007
# 50  Cilastatin + Imipenem + Relebactam                True          789074009
# 51                        Levofloxacin               False          776517005
# 52                           Linezolid               False          776544000
# 53                         Lymecycline               False          776593005
# 54                           Meropenem               False          776694006
# 55             Meropenem + Vaborbactam                True          776695007
# 56                         Methenamine               False          776725009
# 57                       Metronidazole               False          776774005
# 58                         Minocycline         oral  False          776800005
# 59                        Moxifloxacin               False          776831003
# 60                      Nalidixic Acid               False          776859002
# 61                            Neomycin               False          776885003
# 62                      Nitrofurantoin               False          776927008
# 63                         Norfloxacin               False          776943001
# 64                           Ofloxacin               False          776973005
# 65                         Oritavancin               False          777001001
# 66                     Oxytetracycline               False          777035003
# 67             Phenoxymethylpenicillin               False          777175009
# 69           Piperacillin + Tazobactam                True          777212006
# 70                       Pivmecillinam               False          777227006
# 71                       Pristinamycin               False  16251011000001104
# 72           Procaine benzylpenicillin               False         1234762001
# 73                       Spectinomycin               False          777600004
# 74                          Spiramycin               False          777602007
# 75                        Streptomycin  intravenous  False          777614004
# 76                        Sulfadiazine               False          777532008
# 77                      Co-trimoxazole                True  18037511000001104
# 78              Sulfamethoxypyridazine               False          777643007
# 79                       Sulfapyridine               False  15465811000001106
# 80                           Tedizolid               False          777686007
# 81                         Teicoplanin               False          777691008
# 82                          Telavancin               False          777693006
# 83                          Temocillin               False          777700006
# 84                        Tetracycline               False          777730003
# 85                         Tigecycline               False          777769009
# 86                          Tinidazole               False          777775000
# 87                          Tobramycin               False          777791002
# 88                        Trimethoprim               False          777858001
# 89                          Vancomycin               False          777914002
#
#    England-adapted 2019 AWaRe category UK-adapted 2024 AWaRe category  \
# 0                                Watch                          Watch
# 1                               Access                         Access
# 2                                Watch                          Watch
# 3                               Access                         Access
# 4                                Watch                          Watch
# 5                              Reserve                        Reserve
# 6                               Access                         Access
# 7                               Access                         Access
# 8                                Watch                          Watch
# 9                                Watch                         Access
# 10                               Watch                         Access
# 12                               Watch                          Watch
# 13                               Watch                         Access
# 14                               Watch                          Watch
# 15                             Reserve                        Reserve
# 16                               Watch                          Watch
# 17                               Watch                          Watch
# 18                               Watch                          Watch
# 19                               Watch                         Access
# 20                             Reserve                        Reserve
# 21                               Watch                          Watch
# 22                             Reserve                        Reserve
# 23                             Reserve                        Reserve
# 24                             Reserve                        Reserve
# 25                               Watch                          Watch
# 26                               Watch                          Watch
# 27                               Watch                          Watch
# 28                               Watch                          Watch
# 29                               Watch                          Watch
# 30                               Watch                          Watch
# 31                             Reserve                        Reserve
# 32                             Reserve                        Reserve
# 33                             Reserve                        Reserve
# 34                             Reserve                        Reserve
# 35                             Reserve                        Reserve
# 36                               Watch                          Watch
# 37                               Watch                          Other
# 38                             Reserve                        Reserve
# 39                              Access                         Access
# 40                             Reserve                        Reserve
# 41                             Reserve                        Reserve
# 42                               Watch                          Watch
# 43                               Watch                          Watch
# 44                              Access                         Access
# 45                              Access                         Access
# 46                             Reserve                        Reserve
# 47                              Access                          Watch
# 48                              Access                         Access
# 49                             Reserve                        Reserve
# 50                             Reserve                        Reserve
# 51                               Watch                          Watch
# 52                             Reserve                        Reserve
# 53                               Watch                          Watch
# 54                             Reserve                        Reserve
# 55                             Reserve                        Reserve
# 56                               Other                          Other
# 57                              Access                         Access
# 58                               Watch                          Watch
# 59                               Watch                          Watch
# 60                               Other                          Other
# 61                               Watch                          Watch
# 62                              Access                         Access
# 63                               Watch                          Watch
# 64                               Watch                          Watch
# 65                             Reserve                        Reserve
# 66                               Watch                          Watch
# 67                              Access                         Access
# 69                               Watch                          Watch
# 70                              Access                         Access
# 71                               Watch                          Other
# 72                              Access                         Access
# 73                               Other                          Other
# 74                               Other                          Other
# 75                               Other                          Other
# 76                               Other                          Other
# 77                              Access                         Access
# 78                               Other                          Other
# 79                               Other                          Other
# 80                             Reserve                        Reserve
# 81                               Watch                          Watch
# 82                             Reserve                        Reserve
# 83                               Watch                          Watch
# 84                              Access                         Access
# 85                             Reserve                        Reserve
# 86                               Other                         Access
# 87                               Watch                          Watch
# 88                              Access                         Access
# 89                               Watch                          Watch
#
#                                 vtm_nm
# 0                             Amikacin
# 1                          Amoxicillin
# 2                         Co-amoxiclav
# 3                           Ampicillin
# 4                         Azithromycin
# 5                            Aztreonam
# 6          Benzathine benzylpenicillin
# 7                     Benzylpenicillin
# 8                             Cefaclor
# 9                           Cefadroxil
# 10                           Cefalexin
# 12                         Cefamandole
# 13                           Cefazolin
# 14                            Cefepime
# 15                         Cefiderocol
# 16                            Cefixime
# 17                          Cefotaxime
# 18                           Cefoxitin
# 19                           Cefradine
# 20                 Ceftaroline fosamil
# 21                         Ceftazidime
# 22             Ceftazidime + Avibactam
# 23                        Ceftobiprole
# 24            Ceftolozane + Tazobactam
# 25                         Ceftriaxone
# 26                          Cefuroxime
# 27                     Chloramphenicol
# 28                       Ciprofloxacin
# 29                      Clarithromycin
# 30                         Clindamycin
# 31                            Colistin
# 32                            Colistin
# 33                         Dalbavancin
# 34         Quinupristin + Dalfopristin
# 35                          Daptomycin
# 36                        Delafloxacin
# 37                      Demeclocycline
# 38                           Doripenem
# 39                         Doxycycline
# 40                        Eravacycline
# 41                           Ertapenem
# 42                        Erythromycin
# 43                         Fidaxomicin
# 44                      Flucloxacillin
# 45                          Fosfomycin
# 46                          Fosfomycin
# 47                        Fusidic acid
# 48                          Gentamicin
# 49               Imipenem + Cilastatin
# 50  Cilastatin + Imipenem + Relebactam
# 51                        Levofloxacin
# 52                           Linezolid
# 53                         Lymecycline
# 54                           Meropenem
# 55             Meropenem + Vaborbactam
# 56                         Methenamine
# 57                       Metronidazole
# 58                         Minocycline
# 59                        Moxifloxacin
# 60                      Nalidixic acid
# 61                            Neomycin
# 62                      Nitrofurantoin
# 63                         Norfloxacin
# 64                           Ofloxacin
# 65                         Oritavancin
# 66                     Oxytetracycline
# 67             Phenoxymethylpenicillin
# 69           Piperacillin + Tazobactam
# 70                       Pivmecillinam
# 71                       Pristinamycin
# 72           Procaine benzylpenicillin
# 73                       Spectinomycin
# 74                          Spiramycin
# 75                        Streptomycin
# 76                        Sulfadiazine
# 77                      Co-trimoxazole
# 78              Sulfamethoxypyridazine
# 79                       Sulfapyridine
# 80                           Tedizolid
# 81                         Teicoplanin
# 82                          Telavancin
# 83                          Temocillin
# 84                        Tetracycline
# 85                         Tigecycline
# 86                          Tinidazole
# 87                          Tobramycin
# 88                        Trimethoprim
# 89                          Vancomycin

# %% [markdown]
# Seperate out items with and without specified route

# %%
# Ensure 'Route' is a string by replacing NaN with an empty string
df['Route'] = df['Route'].fillna('')

# Create df_no_route: rows where 'Route' is blank (empty or only whitespace)
df_no_route = df[df['Route'].str.strip() == '']

# Create df_route: rows where 'Route' has a value (non-blank)
df_route = df[df['Route'].str.strip() != '']

# %% [markdown]
# Get a list of VMPs from dm+d with VTMs in df_no_route - then match results onto df_no_route based on VTM code

# %%
# Get a list of unique antibiotic values from your DataFrame.
list_of_vtm = df_no_route['vtm_id'].unique().tolist()

# Convert the list into a comma-separated string of quoted values.
formatted_list = ", ".join(f"{vtm}" for vtm in list_of_vtm)

# Construct the query using the formatted list.
sql = f"""
SELECT
  vmp.vtm,
  vmp.id,
  vmp.nm,
  ontformroute.descr  
FROM `ebmdatalab.dmd.vmp` vmp
LEFT JOIN dmd.ont ont ON vmp.id = ont.vmp
LEFT JOIN dmd.ontformroute ontformroute ON ont.form = ontformroute.cd
WHERE vmp.vtm IN({formatted_list})
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vmp_match.csv')

# Use the cached_read function from the bq library to run the query.
vmps_df = bq.cached_read(sql, csv_path=csv_path)

# Rename vtms_df column 'id' to 'vtm_id'
vmps_df = vmps_df.rename(columns={'id': 'vmp_id'})

df_no_route = df_no_route.merge(vmps_df, left_on='vtm_id', right_on='vtm', how='right').drop(columns='vtm')
df_no_route = df_no_route.rename(columns={'nm': 'vmp_nm'})

# %% [markdown]
# Get a list of VMPs from dm+d with VTMs in df_route - then match results onto df_route based on VTM code and route

# %%
# Get a list of unique antibiotic values from your DataFrame.
list_of_vtm = df_route['vtm_id'].unique().tolist()

# Convert the list into a comma-separated string of quoted values.
formatted_list = ", ".join(f"{vtm}" for vtm in list_of_vtm)

# Construct the query using the formatted list.
sql = f"""
SELECT
  vmp.vtm,
  vmp.id,
  vmp.nm,
  ontformroute.descr  
FROM `ebmdatalab.dmd.vmp` vmp
LEFT JOIN dmd.ont ont ON vmp.id = ont.vmp
LEFT JOIN dmd.ontformroute ontformroute ON ont.form = ontformroute.cd
WHERE vmp.vtm IN({formatted_list})
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vmp_match2.csv')

# Use the cached_read function from the bq library to run the query.
vmps_df = bq.cached_read(sql, csv_path=csv_path)

# Rename vtms_df column 'id' to 'vtm_id'
vmps_df = vmps_df.rename(columns={'id': 'vmp_id'})

# Add a column route for matching on
vmps_df['route'] = vmps_df['descr'].str.split(r'\.').str[1]

# Match VMPs
df_route = df_route.merge(
    vmps_df,
    left_on=['vtm_id', 'Route'],
    right_on=['vtm', 'route'],
    how='left'
).assign(vmp_id=lambda x: x['vmp_id'].fillna(0).astype('int64')).drop(columns=['vtm', 'route'])

df_route = df_route.rename(columns={'nm': 'vmp_nm'})

# %% [markdown]
# Combine df_route and df_no_route back together.

# %%
df_combined = pd.concat([df_route, df_no_route], ignore_index=True)

# %% [markdown]
# Check for rows without a VMP match

# %%
df_combined[df_combined['vmp_id'] == 0]
# Out:
#       Antibiotic        Route  Combo     vtm_id  \
# 27  Streptomycin  intravenous  False  777614004
#
#    England-adapted 2019 AWaRe category UK-adapted 2024 AWaRe category  \
# 27                               Other                          Other
#
#           vtm_nm  vmp_id vmp_nm descr
# 27  Streptomycin       0    NaN   NaN

# %% [markdown]
# On manual check Streptomycin 1g powder for solution for injection vials is the only VMP and route is given only as intramuscular-deep so remove from list.

# %%
df_combined = df_combined[df_combined['vmp_id'] != 0]

# %% [markdown]
# Tidy up results

# %%
# Define the desired columns to appear first
cols_first = ['Antibiotic', 'Route', 'Combo', 'vtm_nm', 'vtm_id', 'vmp_nm', 'vmp_id', 'descr']

# Get the list of remaining columns that are not in cols_first
other_cols = [col for col in df_combined.columns if col not in cols_first]

# Reorder the DataFrame columns
df_combined = df_combined[cols_first + other_cols]

# Sort the DataFrame
df_combined = df_combined.sort_values(['Antibiotic', 'vtm_nm', 'vmp_nm'])

# Save to CSV
df_combined.to_csv('AWaRe_VMPs.csv')
