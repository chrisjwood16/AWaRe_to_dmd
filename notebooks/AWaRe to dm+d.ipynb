# %% [markdown]
# ### UK Access, Watch, Reserve, and Other classification for antibiotics in dmd

# %% [markdown]
# The ["UK Access, Watch, Reserve, and Other classification for antibiotics"](https://www.gov.uk/government/publications/uk-aware-antibiotic-classification/uk-access-watch-reserve-and-other-classification-for-antibiotics-uk-aware-antibiotic-classification) categorises antibiotics into groups such as Access, Watch, and Reserve to guide healthcare professionals in optimising their use and mitigating antimicrobial resistance.
#
# The existing list on the UKHSA site is not machine readable. To facilitate research, it is helpful to link this categorisation to the [dm+d standard](https://www.nhsbsa.nhs.uk/pharmacies-gp-practices-and-appliance-contractors/dictionary-medicines-and-devices-dmd).

# %% [markdown]
# ### Imports
# We need to import some libaries to help with the code

# %%
import pandas as pd
import requests
from ebmdatalab import bq
import os

# %% [markdown]
# ### Getting the AWaRe list
# The AWaRe list is currently available on the following webpage. We can read the html page directly into Pandas to retrieve the first table.

# %%
# Set URL to scrape
url = "https://www.gov.uk/government/publications/uk-aware-antibiotic-classification/uk-access-watch-reserve-and-other-classification-for-antibiotics-uk-aware-antibiotic-classification"

# Read the first HTML table from the page into a DataFrame using the HTML content
df_scrape = pd.read_html(url)[0]

# Display the DataFrame
df_scrape
# Out:
#                       Antibiotic England-adapted 2019 AWaRe category  \
# 0                       Amikacin                               Watch
# 1                    Amoxicillin                              Access
# 2   Amoxicillin/ clavulanic-acid                               Watch
# 3                     Ampicillin                              Access
# 4                   Azithromycin                               Watch
# ..                           ...                                 ...
# 85                   Tigecycline                             Reserve
# 86                  Tinidazole #                               Other
# 87                    Tobramycin                               Watch
# 88                  Trimethoprim                              Access
# 89                    Vancomycin                               Watch
#
#    UK-adapted 2024 AWaRe category
# 0                           Watch
# 1                          Access
# 2                           Watch
# 3                          Access
# 4                           Watch
# ..                            ...
# 85                        Reserve
# 86                         Access
# 87                          Watch
# 88                         Access
# 89                          Watch
#
# [90 rows x 3 columns]

# %% [markdown]
# ### Cleaning up the list
# The list contains some characters or identifiers that could break matching, we need to clean these up.

# %% [markdown]
# The # symbol is used to denote where category has changed, remove this

# %%
df_scrape['Antibiotic'] = df_scrape['Antibiotic'].str.replace(" #", "", regex=False)

# %% [markdown]
# We can review remaining rows that contain non-alphabetical characters

# %%
df_scrape[df_scrape['Antibiotic'].str.contains(r'[^A-Za-z ]', na=False)]
# Out:
#                         Antibiotic England-adapted 2019 AWaRe category  \
# 2     Amoxicillin/ clavulanic-acid                               Watch
# 6      Benzathine-benzylpenicillin                              Access
# 20             Ceftaroline-fosamil                             Reserve
# 22          Ceftazidime/ avibactam                             Reserve
# 23          Ceftobiprole-medocaril                             Reserve
# 24         Ceftolozane/ tazobactam                             Reserve
# 31           Colistin, intravenous                             Reserve
# 32                  Colistin, oral                             Reserve
# 34      Dalfopristin/ quinupristin                             Reserve
# 46         Fosfomycin, intravenous                             Reserve
# 49             Imipenem/cilastatin                             Reserve
# 50  Imipenem/cilastatin/relebactam                             Reserve
# 55          Meropenem/ vaborbactam                             Reserve
# 69         Piperacillin/tazobactam                               Watch
# 72       Procaine-benzylpenicillin                              Access
# 75       Streptomycin, intravenous                               Other
# 77  Sulfamethoxazole/ trimethoprim                              Access
#
#    UK-adapted 2024 AWaRe category
# 2                           Watch
# 6                          Access
# 20                        Reserve
# 22                        Reserve
# 23                        Reserve
# 24                        Reserve
# 31                        Reserve
# 32                        Reserve
# 34                        Reserve
# 46                        Reserve
# 49                        Reserve
# 50                        Reserve
# 55                        Reserve
# 69                          Watch
# 72                         Access
# 75                          Other
# 77                         Access

# %% [markdown]
# Some rows specify a route. Sometimes there is a comma between antibiotic and route, sometimes there isn't. We can pull any specified route into a seperate column.

# %%
# List of routes to check.
route_list = ["oral", "intravenous"]

# Function to extract the route if the Antibiotic entry ends with a route.
def extract_route(antibiotic):
    for route in route_list:
        if antibiotic.endswith(" " + route):
            return route
    return ""  # Return empty string if no route is found.

# Apply the function to create a new 'Route' column.
df_scrape['Route_specific'] = df_scrape['Antibiotic'].apply(extract_route)

# Remove any route names from the 'Antibiotic' column only if they appear at the end
# and are preceded by either ", " or " ".
for route in route_list:
    df_scrape['Antibiotic'] = df_scrape['Antibiotic'].str.replace(fr'(, | ){route}$', '', regex=True)

# %%
df_scrape[df_scrape['Antibiotic'].str.contains(r'[^A-Za-z ]', na=False)]
# Out:
#                         Antibiotic England-adapted 2019 AWaRe category  \
# 2     Amoxicillin/ clavulanic-acid                               Watch
# 6      Benzathine-benzylpenicillin                              Access
# 20             Ceftaroline-fosamil                             Reserve
# 22          Ceftazidime/ avibactam                             Reserve
# 23          Ceftobiprole-medocaril                             Reserve
# 24         Ceftolozane/ tazobactam                             Reserve
# 34      Dalfopristin/ quinupristin                             Reserve
# 49             Imipenem/cilastatin                             Reserve
# 50  Imipenem/cilastatin/relebactam                             Reserve
# 55          Meropenem/ vaborbactam                             Reserve
# 69         Piperacillin/tazobactam                               Watch
# 72       Procaine-benzylpenicillin                              Access
# 77  Sulfamethoxazole/ trimethoprim                              Access
#
#    UK-adapted 2024 AWaRe category Route_specific
# 2                           Watch
# 6                          Access
# 20                        Reserve
# 22                        Reserve
# 23                        Reserve
# 24                        Reserve
# 34                        Reserve
# 49                        Reserve
# 50                        Reserve
# 55                        Reserve
# 69                          Watch
# 72                         Access
# 77                         Access

# %% [markdown]
# Some items contain a dash between words where as in dm+d there is a space. Replace the dash with a space to follow the common format.

# %%
df_scrape['Antibiotic'] = df_scrape['Antibiotic'].str.replace("-", " ", regex=False)

# %% [markdown]
# Some items contain a forward slash between words to indicate a combination where as in dm+d there is a + symbol. Replace the dash with a + ensuring appropriately spaced to follow the common dm+d format.

# %%
# Replace / with a + ensuring it is appropriately spaced and 2nd drug name is capitalised
df_scrape['Antibiotic'] = (
    df_scrape['Antibiotic']
    .str.replace(r'\s*/\s*', ' + ', regex=True)
    .str.replace(r'(\+\s+)(\w)', lambda m: m.group(1) + m.group(2).upper(), regex=True)
)
# Create a new column 'Combo' that is True if 'Antibiotic' contains a plus between two words.
df_scrape['Combo'] = df_scrape['Antibiotic'].str.contains(r'\b\w+\s*\+\s*\w+\b', regex=True)

# %%
df_scrape[df_scrape['Antibiotic'].str.contains(r'[^A-Za-z ]', na=False)]
# Out:
#                             Antibiotic England-adapted 2019 AWaRe category  \
# 2        Amoxicillin + Clavulanic acid                               Watch
# 22             Ceftazidime + Avibactam                             Reserve
# 24            Ceftolozane + Tazobactam                             Reserve
# 34         Dalfopristin + Quinupristin                             Reserve
# 49               Imipenem + Cilastatin                             Reserve
# 50  Imipenem + Cilastatin + Relebactam                             Reserve
# 55             Meropenem + Vaborbactam                             Reserve
# 69           Piperacillin + Tazobactam                               Watch
# 77     Sulfamethoxazole + Trimethoprim                              Access
#
#    UK-adapted 2024 AWaRe category Route_specific  Combo
# 2                           Watch                  True
# 22                        Reserve                  True
# 24                        Reserve                  True
# 34                        Reserve                  True
# 49                        Reserve                  True
# 50                        Reserve                  True
# 55                        Reserve                  True
# 69                          Watch                  True
# 77                         Access                  True

# %% [markdown]
# Some antibiotic combinations are referred to as different names or in a different order in dm+d. Convert to use these. (Found these issues via dm+d manual search)

# %%
df_scrape['Antibiotic'] = df_scrape['Antibiotic'].str.replace("Amoxicillin + Clavulanic acid", "Co-amoxiclav", regex=False)
df_scrape['Antibiotic'] = df_scrape['Antibiotic'].str.replace("Sulfamethoxazole + Trimethoprim", "Co-trimoxazole", regex=False)
df_scrape['Antibiotic'] = df_scrape['Antibiotic'].str.replace("Dalfopristin + Quinupristin", "Quinupristin + Dalfopristin", regex=False)
df_scrape['Antibiotic'] = df_scrape['Antibiotic'].str.replace("Imipenem + Cilastatin + Relebactam", "Cilastatin + Imipenem + Relebactam", regex=False)
df_scrape['Antibiotic'] = df_scrape['Antibiotic'].str.replace("Ceftobiprole medocaril", "Ceftobiprole", regex=False)

# %% [markdown]
# Reorder the columns

# %% [markdown]
# Ensure 'Route_specific' is a string by replacing NaN with an empty string
# Add a column 'ATC_Route_specific' mapping 'Route_specific' to ATC route

# %%
# Define mapping
route_map = {'oral': 'O', 'intravenous': 'P'}

# Replace NaN with empty strings just to be safe
df_scrape['Route_specific'] = df_scrape['Route_specific'].fillna('')

# Map values using a dictionary, and fill any unmapped entries with empty string
df_scrape['ATC_Route_specific'] = df_scrape['Route_specific'].map(route_map).fillna('')

# %% [markdown]
# Reorder the columns and rename to simplify

# %%
df_scrape = df_scrape[['Antibiotic', 'Route_specific', 'ATC_Route_specific', 'Combo'] + [col for col in df_scrape.columns if col not in ['Antibiotic', 'Route_specific', 'ATC_Route_specific', 'Combo']]]

df_scrape.rename(columns={'England-adapted 2019 AWaRe category': 'aware_2019'}, inplace=True)
df_scrape.rename(columns={'UK-adapted 2024 AWaRe category': 'aware_2024'}, inplace=True)
df_scrape.rename(columns={'Route_specific': 'route'}, inplace=True)
df_scrape.rename(columns={'ATC_Route_specific': 'atc_route'}, inplace=True)

# Drop un-needed column
df_scrape.drop(columns='Combo', inplace=True)

# %%
df_prepared = df_scrape

with pd.option_context('display.max_rows', None):
    display(df_prepared)
# Out:
#                             Antibiotic        route atc_route aware_2019  \
# 0                             Amikacin                             Watch
# 1                          Amoxicillin                            Access
# 2                         Co-amoxiclav                             Watch
# 3                           Ampicillin                            Access
# 4                         Azithromycin                             Watch
# 5                            Aztreonam                           Reserve
# 6          Benzathine benzylpenicillin                            Access
# 7                     Benzylpenicillin                            Access
# 8                             Cefaclor                             Watch
# 9                           Cefadroxil                             Watch
# 10                           Cefalexin                             Watch
# 11                           Cefalotin                             Watch
# 12                         Cefamandole                             Watch
# 13                           Cefazolin                             Watch
# 14                            Cefepime                             Watch
# 15                         Cefiderocol                           Reserve
# 16                            Cefixime                             Watch
# 17                          Cefotaxime                             Watch
# 18                           Cefoxitin                             Watch
# 19                           Cefradine                             Watch
# 20                 Ceftaroline fosamil                           Reserve
# 21                         Ceftazidime                             Watch
# 22             Ceftazidime + Avibactam                           Reserve
# 23                        Ceftobiprole                           Reserve
# 24            Ceftolozane + Tazobactam                           Reserve
# 25                         Ceftriaxone                             Watch
# 26                          Cefuroxime                             Watch
# 27                     Chloramphenicol                             Watch
# 28                       Ciprofloxacin                             Watch
# 29                      Clarithromycin                             Watch
# 30                         Clindamycin                             Watch
# 31                            Colistin  intravenous         P    Reserve
# 32                            Colistin         oral         O    Reserve
# 33                         Dalbavancin                           Reserve
# 34         Quinupristin + Dalfopristin                           Reserve
# 35                          Daptomycin                           Reserve
# 36                        Delafloxacin                             Watch
# 37                      Demeclocycline                             Watch
# 38                           Doripenem                           Reserve
# 39                         Doxycycline                            Access
# 40                        Eravacycline                           Reserve
# 41                           Ertapenem                           Reserve
# 42                        Erythromycin                             Watch
# 43                         Fidaxomicin                             Watch
# 44                      Flucloxacillin                            Access
# 45                          Fosfomycin         oral         O     Access
# 46                          Fosfomycin  intravenous         P    Reserve
# 47                        Fusidic acid                            Access
# 48                          Gentamicin                            Access
# 49               Imipenem + Cilastatin                           Reserve
# 50  Cilastatin + Imipenem + Relebactam                           Reserve
# 51                        Levofloxacin                             Watch
# 52                           Linezolid                           Reserve
# 53                         Lymecycline                             Watch
# 54                           Meropenem                           Reserve
# 55             Meropenem + Vaborbactam                           Reserve
# 56                         Methenamine                             Other
# 57                       Metronidazole                            Access
# 58                         Minocycline         oral         O      Watch
# 59                        Moxifloxacin                             Watch
# 60                      Nalidixic Acid                             Other
# 61                            Neomycin                             Watch
# 62                      Nitrofurantoin                            Access
# 63                         Norfloxacin                             Watch
# 64                           Ofloxacin                             Watch
# 65                         Oritavancin                           Reserve
# 66                     Oxytetracycline                             Watch
# 67             Phenoxymethylpenicillin                            Access
# 68                        Piperacillin                             Watch
# 69           Piperacillin + Tazobactam                             Watch
# 70                       Pivmecillinam                            Access
# 71                       Pristinamycin                             Watch
# 72           Procaine benzylpenicillin                            Access
# 73                       Spectinomycin                             Other
# 74                          Spiramycin                             Other
# 75                        Streptomycin  intravenous         P      Other
# 76                        Sulfadiazine                             Other
# 77                      Co-trimoxazole                            Access
# 78              Sulfamethoxypyridazine                             Other
# 79                       Sulfapyridine                             Other
# 80                           Tedizolid                           Reserve
# 81                         Teicoplanin                             Watch
# 82                          Telavancin                           Reserve
# 83                          Temocillin                             Watch
# 84                        Tetracycline                            Access
# 85                         Tigecycline                           Reserve
# 86                          Tinidazole                             Other
# 87                          Tobramycin                             Watch
# 88                        Trimethoprim                            Access
# 89                          Vancomycin                             Watch
#
#    aware_2024
# 0       Watch
# 1      Access
# 2       Watch
# 3      Access
# 4       Watch
# 5     Reserve
# 6      Access
# 7      Access
# 8       Watch
# 9      Access
# 10     Access
# 11     Access
# 12      Watch
# 13     Access
# 14      Watch
# 15    Reserve
# 16      Watch
# 17      Watch
# 18      Watch
# 19     Access
# 20    Reserve
# 21      Watch
# 22    Reserve
# 23    Reserve
# 24    Reserve
# 25      Watch
# 26      Watch
# 27      Watch
# 28      Watch
# 29      Watch
# 30      Watch
# 31    Reserve
# 32    Reserve
# 33    Reserve
# 34    Reserve
# 35    Reserve
# 36      Watch
# 37      Other
# 38    Reserve
# 39     Access
# 40    Reserve
# 41    Reserve
# 42      Watch
# 43      Watch
# 44     Access
# 45     Access
# 46    Reserve
# 47      Watch
# 48     Access
# 49    Reserve
# 50    Reserve
# 51      Watch
# 52    Reserve
# 53      Watch
# 54    Reserve
# 55    Reserve
# 56      Other
# 57     Access
# 58      Watch
# 59      Watch
# 60      Other
# 61      Watch
# 62     Access
# 63      Watch
# 64      Watch
# 65    Reserve
# 66      Watch
# 67     Access
# 68      Watch
# 69      Watch
# 70     Access
# 71      Other
# 72     Access
# 73      Other
# 74      Other
# 75      Other
# 76      Other
# 77     Access
# 78      Other
# 79      Other
# 80    Reserve
# 81      Watch
# 82    Reserve
# 83      Watch
# 84     Access
# 85    Reserve
# 86     Access
# 87      Watch
# 88     Access
# 89      Watch

# %% [markdown]
# We can save this as a CSV amd upload as a table in BigQuery for further processing. `ebmdatalab.chris.aware_prepared`

# %%
csv_path = os.path.join('..', 'data', 'AWaRe_prepared.csv')
df_prepared.to_csv(csv_path, index=False)

# %% [markdown]
# ### Matching to VTMs

# %% [markdown]
# We can attempt to match Antibiotic names in the UKHSA to VTMs in dm+d

# %%
sql = f"""
  SELECT  
    aware.Antibiotic,
    aware.atc_route,
    aware.aware_2019,
    aware.aware_2024,
    vtm.nm,
    CASE
      WHEN aware.Antibiotic = vtm.nm THEN 'DIRECT'
      ELSE 'ASSUMED'
    END AS match_type
  FROM `ebmdatalab.chris.aware_list` aware
  LEFT JOIN `ebmdatalab.dmd.vtm` vtm 
    ON vtm.nm = aware.Antibiotic
  WHERE vtm.invalid IS NOT TRUE
  ORDER BY Antibiotic ASC
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vtm_match.csv')

# Use the cached_read function from the bq library to run the query.
vtm_match = bq.cached_read(sql, csv_path=csv_path)

with pd.option_context('display.max_rows', None):
    display(vtm_match)
# Out:
#                             Antibiotic atc_route aware_2019 aware_2024  \
# 0                             Amikacin       NaN      Watch      Watch
# 1                          Amoxicillin       NaN     Access     Access
# 2                           Ampicillin       NaN     Access     Access
# 3                         Azithromycin       NaN      Watch      Watch
# 4                            Aztreonam       NaN    Reserve    Reserve
# 5          Benzathine benzylpenicillin       NaN     Access     Access
# 6                     Benzylpenicillin       NaN     Access     Access
# 7                             Cefaclor       NaN      Watch      Watch
# 8                           Cefadroxil       NaN      Watch     Access
# 9                            Cefalexin       NaN      Watch     Access
# 10                           Cefalotin       NaN      Watch     Access
# 11                         Cefamandole       NaN      Watch      Watch
# 12                           Cefazolin       NaN      Watch     Access
# 13                            Cefepime       NaN      Watch      Watch
# 14                         Cefiderocol       NaN    Reserve    Reserve
# 15                            Cefixime       NaN      Watch      Watch
# 16                          Cefotaxime       NaN      Watch      Watch
# 17                           Cefoxitin       NaN      Watch      Watch
# 18                           Cefradine       NaN      Watch     Access
# 19                 Ceftaroline fosamil       NaN    Reserve    Reserve
# 20                         Ceftazidime       NaN      Watch      Watch
# 21             Ceftazidime + Avibactam       NaN    Reserve    Reserve
# 22                        Ceftobiprole       NaN    Reserve    Reserve
# 23            Ceftolozane + Tazobactam       NaN    Reserve    Reserve
# 24                         Ceftriaxone       NaN      Watch      Watch
# 25                          Cefuroxime       NaN      Watch      Watch
# 26                     Chloramphenicol       NaN      Watch      Watch
# 27  Cilastatin + Imipenem + Relebactam       NaN    Reserve    Reserve
# 28                       Ciprofloxacin       NaN      Watch      Watch
# 29                      Clarithromycin       NaN      Watch      Watch
# 30                         Clindamycin       NaN      Watch      Watch
# 31                        Co-amoxiclav       NaN      Watch      Watch
# 32                      Co-trimoxazole       NaN     Access     Access
# 33                            Colistin         P    Reserve    Reserve
# 34                            Colistin         O    Reserve    Reserve
# 35                         Dalbavancin       NaN    Reserve    Reserve
# 36                          Daptomycin       NaN    Reserve    Reserve
# 37                        Delafloxacin       NaN      Watch      Watch
# 38                      Demeclocycline       NaN      Watch      Other
# 39                           Doripenem       NaN    Reserve    Reserve
# 40                         Doxycycline       NaN     Access     Access
# 41                        Eravacycline       NaN    Reserve    Reserve
# 42                           Ertapenem       NaN    Reserve    Reserve
# 43                        Erythromycin       NaN      Watch      Watch
# 44                         Fidaxomicin       NaN      Watch      Watch
# 45                      Flucloxacillin       NaN     Access     Access
# 46                          Fosfomycin         P    Reserve    Reserve
# 47                          Fosfomycin         O     Access     Access
# 48                        Fusidic acid       NaN     Access      Watch
# 49                          Gentamicin       NaN     Access     Access
# 50               Imipenem + Cilastatin       NaN    Reserve    Reserve
# 51                        Levofloxacin       NaN      Watch      Watch
# 52                           Linezolid       NaN    Reserve    Reserve
# 53                         Lymecycline       NaN      Watch      Watch
# 54                           Meropenem       NaN    Reserve    Reserve
# 55             Meropenem + Vaborbactam       NaN    Reserve    Reserve
# 56                         Methenamine       NaN      Other      Other
# 57                       Metronidazole       NaN     Access     Access
# 58                         Minocycline         O      Watch      Watch
# 59                        Moxifloxacin       NaN      Watch      Watch
# 60                      Nalidixic Acid       NaN      Other      Other
# 61                            Neomycin       NaN      Watch      Watch
# 62                      Nitrofurantoin       NaN     Access     Access
# 63                         Norfloxacin       NaN      Watch      Watch
# 64                           Ofloxacin       NaN      Watch      Watch
# 65                         Oritavancin       NaN    Reserve    Reserve
# 66                     Oxytetracycline       NaN      Watch      Watch
# 67             Phenoxymethylpenicillin       NaN     Access     Access
# 68                        Piperacillin       NaN      Watch      Watch
# 69           Piperacillin + Tazobactam       NaN      Watch      Watch
# 70                       Pivmecillinam       NaN     Access     Access
# 71                       Pristinamycin       NaN      Watch      Other
# 72           Procaine benzylpenicillin       NaN     Access     Access
# 73         Quinupristin + Dalfopristin       NaN    Reserve    Reserve
# 74                       Spectinomycin       NaN      Other      Other
# 75                          Spiramycin       NaN      Other      Other
# 76                        Streptomycin         P      Other      Other
# 77                        Sulfadiazine       NaN      Other      Other
# 78              Sulfamethoxypyridazine       NaN      Other      Other
# 79                       Sulfapyridine       NaN      Other      Other
# 80                           Tedizolid       NaN    Reserve    Reserve
# 81                         Teicoplanin       NaN      Watch      Watch
# 82                          Telavancin       NaN    Reserve    Reserve
# 83                          Temocillin       NaN      Watch      Watch
# 84                        Tetracycline       NaN     Access     Access
# 85                         Tigecycline       NaN    Reserve    Reserve
# 86                          Tinidazole       NaN      Other     Access
# 87                          Tobramycin       NaN      Watch      Watch
# 88                        Trimethoprim       NaN     Access     Access
# 89                          Vancomycin       NaN      Watch      Watch
#
#                                     nm match_type
# 0                             Amikacin     DIRECT
# 1                          Amoxicillin     DIRECT
# 2                           Ampicillin     DIRECT
# 3                         Azithromycin     DIRECT
# 4                            Aztreonam     DIRECT
# 5          Benzathine benzylpenicillin     DIRECT
# 6                     Benzylpenicillin     DIRECT
# 7                             Cefaclor     DIRECT
# 8                           Cefadroxil     DIRECT
# 9                            Cefalexin     DIRECT
# 10                                 NaN    ASSUMED
# 11                         Cefamandole     DIRECT
# 12                           Cefazolin     DIRECT
# 13                            Cefepime     DIRECT
# 14                         Cefiderocol     DIRECT
# 15                            Cefixime     DIRECT
# 16                          Cefotaxime     DIRECT
# 17                           Cefoxitin     DIRECT
# 18                           Cefradine     DIRECT
# 19                 Ceftaroline fosamil     DIRECT
# 20                         Ceftazidime     DIRECT
# 21             Ceftazidime + Avibactam     DIRECT
# 22                        Ceftobiprole     DIRECT
# 23            Ceftolozane + Tazobactam     DIRECT
# 24                         Ceftriaxone     DIRECT
# 25                          Cefuroxime     DIRECT
# 26                     Chloramphenicol     DIRECT
# 27  Cilastatin + Imipenem + Relebactam     DIRECT
# 28                       Ciprofloxacin     DIRECT
# 29                      Clarithromycin     DIRECT
# 30                         Clindamycin     DIRECT
# 31                        Co-amoxiclav     DIRECT
# 32                      Co-trimoxazole     DIRECT
# 33                            Colistin     DIRECT
# 34                            Colistin     DIRECT
# 35                         Dalbavancin     DIRECT
# 36                          Daptomycin     DIRECT
# 37                        Delafloxacin     DIRECT
# 38                      Demeclocycline     DIRECT
# 39                           Doripenem     DIRECT
# 40                         Doxycycline     DIRECT
# 41                        Eravacycline     DIRECT
# 42                           Ertapenem     DIRECT
# 43                        Erythromycin     DIRECT
# 44                         Fidaxomicin     DIRECT
# 45                      Flucloxacillin     DIRECT
# 46                          Fosfomycin     DIRECT
# 47                          Fosfomycin     DIRECT
# 48                        Fusidic acid     DIRECT
# 49                          Gentamicin     DIRECT
# 50               Imipenem + Cilastatin     DIRECT
# 51                        Levofloxacin     DIRECT
# 52                           Linezolid     DIRECT
# 53                         Lymecycline     DIRECT
# 54                           Meropenem     DIRECT
# 55             Meropenem + Vaborbactam     DIRECT
# 56                         Methenamine     DIRECT
# 57                       Metronidazole     DIRECT
# 58                         Minocycline     DIRECT
# 59                        Moxifloxacin     DIRECT
# 60                                 NaN    ASSUMED
# 61                            Neomycin     DIRECT
# 62                      Nitrofurantoin     DIRECT
# 63                         Norfloxacin     DIRECT
# 64                           Ofloxacin     DIRECT
# 65                         Oritavancin     DIRECT
# 66                     Oxytetracycline     DIRECT
# 67             Phenoxymethylpenicillin     DIRECT
# 68                                 NaN    ASSUMED
# 69           Piperacillin + Tazobactam     DIRECT
# 70                       Pivmecillinam     DIRECT
# 71                       Pristinamycin     DIRECT
# 72           Procaine benzylpenicillin     DIRECT
# 73         Quinupristin + Dalfopristin     DIRECT
# 74                       Spectinomycin     DIRECT
# 75                          Spiramycin     DIRECT
# 76                        Streptomycin     DIRECT
# 77                        Sulfadiazine     DIRECT
# 78              Sulfamethoxypyridazine     DIRECT
# 79                       Sulfapyridine     DIRECT
# 80                           Tedizolid     DIRECT
# 81                         Teicoplanin     DIRECT
# 82                          Telavancin     DIRECT
# 83                          Temocillin     DIRECT
# 84                        Tetracycline     DIRECT
# 85                         Tigecycline     DIRECT
# 86                          Tinidazole     DIRECT
# 87                          Tobramycin     DIRECT
# 88                        Trimethoprim     DIRECT
# 89                          Vancomycin     DIRECT

# %% [markdown]
# This works to match VTMs to many of the listing. But doesn't capture where there are multiple VTM matches - for example Amikacin and Amikacin liposomal for Amikacin.
#
# We can use more fuzzy matching to get greater sensitivity in the matches.

# %%
sql = f"""
  SELECT  
    aware.Antibiotic,
    aware.atc_route,
    aware.aware_2019,
    aware.aware_2024,
    vtm.nm,
    CASE
      WHEN aware.Antibiotic = vtm.nm THEN 'DIRECT'
      ELSE 'ASSUMED'
    END AS match_type
  FROM `ebmdatalab.chris.aware_list` aware
  LEFT JOIN `ebmdatalab.dmd.vtm` vtm 
    ON vtm.nm LIKE CONCAT('%', aware.Antibiotic, '%')
  WHERE vtm.invalid IS NOT TRUE
  ORDER BY Antibiotic ASC
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vtm_fuzzy_match.csv')

# Use the cached_read function from the bq library to run the query.
vtm_fuzzy_match = bq.cached_read(sql, csv_path=csv_path)

with pd.option_context('display.max_rows', None):
    display(vtm_fuzzy_match)
# Out:
#                              Antibiotic atc_route aware_2019 aware_2024  \
# 0                              Amikacin       NaN      Watch      Watch
# 1                              Amikacin       NaN      Watch      Watch
# 2                           Amoxicillin       NaN     Access     Access
# 63                       Flucloxacillin       NaN     Access     Access
# 64                       Flucloxacillin       NaN     Access     Access
# 65                           Fosfomycin         P    Reserve    Reserve
# 66                           Fosfomycin         O     Access     Access
# 67                         Fusidic acid       NaN     Access      Watch
# 68                         Fusidic acid       NaN     Access      Watch
# 69                         Fusidic acid       NaN     Access      Watch
# 70                           Gentamicin       NaN     Access     Access
# 71                           Gentamicin       NaN     Access     Access
# 72                Imipenem + Cilastatin       NaN    Reserve    Reserve
# 73                         Levofloxacin       NaN      Watch      Watch
# 74                         Levofloxacin       NaN      Watch      Watch
# 75                            Linezolid       NaN    Reserve    Reserve
# 76                          Lymecycline       NaN      Watch      Watch
# 77                            Meropenem       NaN    Reserve    Reserve
# 78                            Meropenem       NaN    Reserve    Reserve
# 79              Meropenem + Vaborbactam       NaN    Reserve    Reserve
# 80                          Methenamine       NaN      Other      Other
# 81                        Metronidazole       NaN     Access     Access
# 82                          Minocycline         O      Watch      Watch
# 83                         Moxifloxacin       NaN      Watch      Watch
# 84                       Nalidixic Acid       NaN      Other      Other
# 85                             Neomycin       NaN      Watch      Watch
# 86                             Neomycin       NaN      Watch      Watch
# 87                             Neomycin       NaN      Watch      Watch
# 88                             Neomycin       NaN      Watch      Watch
# 89                             Neomycin       NaN      Watch      Watch
# 90                             Neomycin       NaN      Watch      Watch
# 91                             Neomycin       NaN      Watch      Watch
# 92                             Neomycin       NaN      Watch      Watch
# 93                             Neomycin       NaN      Watch      Watch
# 94                       Nitrofurantoin       NaN     Access     Access
# 95                          Norfloxacin       NaN      Watch      Watch
# 96                            Ofloxacin       NaN      Watch      Watch
# 97                          Oritavancin       NaN    Reserve    Reserve
# 98                      Oxytetracycline       NaN      Watch      Watch
# 99                      Oxytetracycline       NaN      Watch      Watch
# 100                     Oxytetracycline       NaN      Watch      Watch
# 101             Phenoxymethylpenicillin       NaN     Access     Access
# 102                        Piperacillin       NaN      Watch      Watch
# 103           Piperacillin + Tazobactam       NaN      Watch      Watch
# 104                       Pivmecillinam       NaN     Access     Access
# 105                       Pristinamycin       NaN      Watch      Other
# 106           Procaine benzylpenicillin       NaN     Access     Access
# 107         Quinupristin + Dalfopristin       NaN    Reserve    Reserve
# 108                       Spectinomycin       NaN      Other      Other
# 109                          Spiramycin       NaN      Other      Other
# 110                        Streptomycin         P      Other      Other
# 111                        Sulfadiazine       NaN      Other      Other
# 112                        Sulfadiazine       NaN      Other      Other
# 113                        Sulfadiazine       NaN      Other      Other
# 114              Sulfamethoxypyridazine       NaN      Other      Other
# 115                       Sulfapyridine       NaN      Other      Other
# 116                           Tedizolid       NaN    Reserve    Reserve
# 117                         Teicoplanin       NaN      Watch      Watch
# 118                          Telavancin       NaN    Reserve    Reserve
# 119                          Temocillin       NaN      Watch      Watch
# 120                        Tetracycline       NaN     Access     Access
# 121                         Tigecycline       NaN    Reserve    Reserve
# 122                          Tinidazole       NaN      Other     Access
# 123                          Tobramycin       NaN      Watch      Watch
# 124                          Tobramycin       NaN      Watch      Watch
# 125                        Trimethoprim       NaN     Access     Access
# 126                        Trimethoprim       NaN     Access     Access
# 127                          Vancomycin       NaN      Watch      Watch
#
#                                            nm match_type
# 0                          Amikacin liposomal    ASSUMED
# 1                                    Amikacin     DIRECT
# 2                                 Amoxicillin     DIRECT
# 3                                  Ampicillin     DIRECT
# 4                 Ampicillin + Flucloxacillin    ASSUMED
# 5                                Azithromycin     DIRECT
# 6                       Aztreonam + Avibactam    ASSUMED
# 7                                   Aztreonam     DIRECT
# 8                 Benzathine benzylpenicillin     DIRECT
# 9                            Benzylpenicillin     DIRECT
# 10                                   Cefaclor     DIRECT
# 11                                 Cefadroxil     DIRECT
# 12                                  Cefalexin     DIRECT
# 13                                        NaN    ASSUMED
# 14                                Cefamandole     DIRECT
# 15                                  Cefazolin     DIRECT
# 16                  Cefepime + Enmetazobactam    ASSUMED
# 17                                   Cefepime     DIRECT
# 18                                Cefiderocol     DIRECT
# 19                                   Cefixime     DIRECT
# 20                                 Cefotaxime     DIRECT
# 21                                  Cefoxitin     DIRECT
# 22                                  Cefradine     DIRECT
# 23                        Ceftaroline fosamil     DIRECT
# 24                    Ceftazidime + Avibactam    ASSUMED
# 25                                Ceftazidime     DIRECT
# 26                    Ceftazidime + Avibactam     DIRECT
# 27                               Ceftobiprole     DIRECT
# 28                   Ceftolozane + Tazobactam     DIRECT
# 29                                Ceftriaxone     DIRECT
# 30                                 Cefuroxime     DIRECT
# 31                            Chloramphenicol     DIRECT
# 32         Cilastatin + Imipenem + Relebactam     DIRECT
# 33              Ciprofloxacin + Dexamethasone    ASSUMED
# 34                              Ciprofloxacin     DIRECT
# 35     Ciprofloxacin + Fluocinolone acetonide    ASSUMED
# 36                             Clarithromycin     DIRECT
# 37                    Clindamycin + Tretinoin    ASSUMED
# 38               Clindamycin + Hydrocortisone    ASSUMED
# 39                                Clindamycin     DIRECT
# 40             Benzoyl peroxide + Clindamycin    ASSUMED
# 41                               Co-amoxiclav     DIRECT
# 42                             Co-trimoxazole     DIRECT
# 43                                   Colistin     DIRECT
# 44                                   Colistin     DIRECT
# 45                                Dalbavancin     DIRECT
# 46                                 Daptomycin     DIRECT
# 47                               Delafloxacin     DIRECT
# 48                             Demeclocycline     DIRECT
# 49                                  Doripenem     DIRECT
# 50     Betamethasone + Doxycycline + Nystatin    ASSUMED
# 51                                Doxycycline     DIRECT
# 52                               Eravacycline     DIRECT
# 53                                  Ertapenem     DIRECT
# 54                Erythromycin + Zinc acetate    ASSUMED
# 55                   Tretinoin + Erythromycin    ASSUMED
# 56                Isotretinoin + Erythromycin    ASSUMED
# 57                  Erythromycin lactobionate    ASSUMED
# 58                               Erythromycin     DIRECT
# 59            Benzoyl peroxide + Erythromycin    ASSUMED
# 60               Erythromycin ethyl succinate    ASSUMED
# 61                      Erythromycin stearate    ASSUMED
# 62                                Fidaxomicin     DIRECT
# 63                             Flucloxacillin     DIRECT
# 64                Ampicillin + Flucloxacillin    ASSUMED
# 65                                 Fosfomycin     DIRECT
# 66                                 Fosfomycin     DIRECT
# 67                               Fusidic acid     DIRECT
# 68               Betamethasone + Fusidic acid    ASSUMED
# 69              Hydrocortisone + Fusidic acid    ASSUMED
# 70                Gentamicin + Hydrocortisone    ASSUMED
# 71                                 Gentamicin     DIRECT
# 72                      Imipenem + Cilastatin     DIRECT
# 73                               Levofloxacin     DIRECT
# 74               Dexamethasone + Levofloxacin    ASSUMED
# 75                                  Linezolid     DIRECT
# 76                                Lymecycline     DIRECT
# 77                                  Meropenem     DIRECT
# 78                    Meropenem + Vaborbactam    ASSUMED
# 79                    Meropenem + Vaborbactam     DIRECT
# 80                                Methenamine     DIRECT
# 81                              Metronidazole     DIRECT
# 82                                Minocycline     DIRECT
# 83                               Moxifloxacin     DIRECT
# 84                                        NaN    ASSUMED
# 85           Clobetasol + Neomycin + Nystatin    ASSUMED
# 86                   Betamethasone + Neomycin    ASSUMED
# 87                      Neomycin + Gramicidin    ASSUMED
# 88                   Neomycin + Chlorhexidine    ASSUMED
# 89                                   Neomycin     DIRECT
# 90                  Hydrocortisone + Neomycin    ASSUMED
# 91          Fluocinolone acetonide + Neomycin    ASSUMED
# 92                   Neomycin + Triamcinolone    ASSUMED
# 93                    Neomycin + Prednisolone    ASSUMED
# 94                             Nitrofurantoin     DIRECT
# 95                                Norfloxacin     DIRECT
# 96                                  Ofloxacin     DIRECT
# 97                                Oritavancin     DIRECT
# 98           Oxytetracycline + Hydrocortisone    ASSUMED
# 99                            Oxytetracycline     DIRECT
# 100  Clobetasone + Oxytetracycline + Nystatin    ASSUMED
# 101                   Phenoxymethylpenicillin     DIRECT
# 102                 Piperacillin + Tazobactam    ASSUMED
# 103                 Piperacillin + Tazobactam     DIRECT
# 104                             Pivmecillinam     DIRECT
# 105                             Pristinamycin     DIRECT
# 106                 Procaine benzylpenicillin     DIRECT
# 107               Quinupristin + Dalfopristin     DIRECT
# 108                             Spectinomycin     DIRECT
# 109                                Spiramycin     DIRECT
# 110                              Streptomycin     DIRECT
# 111      Cerium nitrate + Sulfadiazine silver    ASSUMED
# 112                              Sulfadiazine     DIRECT
# 113                       Sulfadiazine silver    ASSUMED
# 114                    Sulfamethoxypyridazine     DIRECT
# 115                             Sulfapyridine     DIRECT
# 116                                 Tedizolid     DIRECT
# 117                               Teicoplanin     DIRECT
# 118                                Telavancin     DIRECT
# 119                                Temocillin     DIRECT
# 120                              Tetracycline     DIRECT
# 121                               Tigecycline     DIRECT
# 122                                Tinidazole     DIRECT
# 123                                Tobramycin     DIRECT
# 124                Dexamethasone + Tobramycin    ASSUMED
# 125                              Trimethoprim     DIRECT
# 126                Polymyxin B + Trimethoprim    ASSUMED
# 127                                Vancomycin     DIRECT

# %% [markdown]
# This gives a number of duplicate matches - for example Meropenem + Vaborbactam matches to both Meropenem and Meropenem + Vaborbactam
#
# We can look for all the duplicates

# %%
sql = f"""
WITH matched_vtms AS (
  SELECT  
    aware.Antibiotic,
    aware.atc_route,
    aware.aware_2019,
    aware.aware_2024,
    vtm.nm,
    CASE
      WHEN aware.Antibiotic = vtm.nm THEN 'DIRECT'
      ELSE 'ASSUMED'
    END AS match_type
  FROM `ebmdatalab.chris.aware_list` aware
  LEFT JOIN `ebmdatalab.dmd.vtm` vtm 
    ON vtm.nm LIKE CONCAT('%', aware.Antibiotic, '%')
  WHERE vtm.invalid IS NOT TRUE
)

SELECT *
FROM matched_vtms
WHERE nm IN (
  SELECT nm
  FROM matched_vtms
  WHERE atc_route IS NULL
  GROUP BY nm
  HAVING COUNT(*) > 1
)
ORDER BY Antibiotic ASC;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vtm_duplicates.csv')

# Use the cached_read function from the bq library to run the query.
vtm_duplicates = bq.cached_read(sql, csv_path=csv_path)

with pd.option_context('display.max_rows', None):
    display(vtm_duplicates)
# Out:
#                   Antibiotic  atc_route aware_2019 aware_2024  \
# 0                 Ampicillin        NaN     Access     Access
# 1                Ceftazidime        NaN      Watch      Watch
# 2    Ceftazidime + Avibactam        NaN    Reserve    Reserve
# 3             Flucloxacillin        NaN     Access     Access
# 4                  Meropenem        NaN    Reserve    Reserve
# 5    Meropenem + Vaborbactam        NaN    Reserve    Reserve
# 6               Piperacillin        NaN      Watch      Watch
# 7  Piperacillin + Tazobactam        NaN      Watch      Watch
#
#                             nm match_type
# 0  Ampicillin + Flucloxacillin    ASSUMED
# 1      Ceftazidime + Avibactam    ASSUMED
# 2      Ceftazidime + Avibactam     DIRECT
# 3  Ampicillin + Flucloxacillin    ASSUMED
# 4      Meropenem + Vaborbactam    ASSUMED
# 5      Meropenem + Vaborbactam     DIRECT
# 6    Piperacillin + Tazobactam    ASSUMED
# 7    Piperacillin + Tazobactam     DIRECT

# %% [markdown]
# From this we can create a list of the unwanted duplicates to remove from our full list.

# %%
sql = f"""
WITH matched_vtms AS (
  SELECT  
    aware.Antibiotic,
    aware.atc_route,
    aware.aware_2019,
    aware.aware_2024,
    vtm.nm,
    CASE
      WHEN aware.Antibiotic = vtm.nm THEN 'DIRECT'
      ELSE 'ASSUMED'
    END AS match_type
  FROM `ebmdatalab.chris.aware_list` aware
  LEFT JOIN `ebmdatalab.dmd.vtm` vtm 
    ON vtm.nm LIKE CONCAT('%', aware.Antibiotic, '%')
  WHERE vtm.invalid IS NOT TRUE
)

SELECT *
FROM matched_vtms
WHERE nm IN (
  SELECT nm
  FROM matched_vtms
  WHERE atc_route IS NULL
  GROUP BY nm
  HAVING COUNT(*) > 1
) AND match_type = 'ASSUMED' 
    AND NOT (Antibiotic='Ampicillin' AND nm='Ampicillin + Flucloxacillin')
ORDER BY Antibiotic ASC;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vtm_duplicates_direct.csv')

# Use the cached_read function from the bq library to run the query.
vtm_duplicates_direct = bq.cached_read(sql, csv_path=csv_path)

with pd.option_context('display.max_rows', None):
    display(vtm_duplicates_direct)
# Out:
#        Antibiotic  atc_route aware_2019 aware_2024  \
# 0     Ceftazidime        NaN      Watch      Watch
# 1  Flucloxacillin        NaN     Access     Access
# 2       Meropenem        NaN    Reserve    Reserve
# 3    Piperacillin        NaN      Watch      Watch
#
#                             nm match_type
# 0      Ceftazidime + Avibactam    ASSUMED
# 1  Ampicillin + Flucloxacillin    ASSUMED
# 2      Meropenem + Vaborbactam    ASSUMED
# 3    Piperacillin + Tazobactam    ASSUMED

# %% [markdown]
# We can then create a full list of potential VTMs with duplicates removed.

# %%
sql = f"""
WITH matched_vtms AS ( -- This query does the fuzzy matching of Antibiotic name to VTM name
  SELECT  
    aware.Antibiotic,
    aware.atc_route,
    aware.aware_2019,
    aware.aware_2024,
    vtm.nm,
    vtm.id,
    CASE
      WHEN aware.Antibiotic = vtm.nm THEN 'DIRECT'
      ELSE 'ASSUMED'
    END AS match_type
  FROM `ebmdatalab.chris.aware_list` aware
  LEFT JOIN `ebmdatalab.dmd.vtm` vtm 
    ON vtm.nm LIKE CONCAT('%', aware.Antibiotic, '%')
  WHERE vtm.invalid IS NOT TRUE
),

manual_exceptions AS ( -- This is a list of manual exceptions used when recluding assumed matches
  SELECT 'Ampicillin' AS Antibiotic, 'Ampicillin + Flucloxacillin' AS nm
  -- Add more rows here as needed
),

duplicate_vtms AS ( -- This produces a list of duplicate rows where a direct match already exists
  SELECT *
  FROM matched_vtms
  WHERE nm IN (
    SELECT nm
    FROM matched_vtms
    WHERE atc_route IS NULL
    GROUP BY nm
    HAVING COUNT(*) > 1
  )
  AND match_type = 'ASSUMED'
  AND NOT EXISTS (
    SELECT 1
    FROM manual_exceptions e
    WHERE e.Antibiotic = matched_vtms.Antibiotic AND e.nm = matched_vtms.nm
  )
)

SELECT
  matched_vtms.Antibiotic,
  matched_vtms.nm,
  matched_vtms.id,
  matched_vtms.atc_route,
  matched_vtms.aware_2019,
  matched_vtms.aware_2024,
FROM matched_vtms
WHERE NOT EXISTS ( -- removes the duplicates identified above
  SELECT 1
  FROM duplicate_vtms
  WHERE matched_vtms.Antibiotic = duplicate_vtms.Antibiotic AND matched_vtms.nm = duplicate_vtms.nm
)
ORDER BY matched_vtms.Antibiotic ASC;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vtm_match_cleaned.csv')

# Use the cached_read function from the bq library to run the query.
vtm_match_cleaned = bq.cached_read(sql, csv_path=csv_path)

with pd.option_context('display.max_rows', None):
    display(vtm_match_cleaned)
# Out:
#                              Antibiotic  \
# 0                              Amikacin
# 1                              Amikacin
# 2                           Amoxicillin
# 3                            Ampicillin
# 4                            Ampicillin
# 5                          Azithromycin
# 6                             Aztreonam
# 7                             Aztreonam
# 8           Benzathine benzylpenicillin
# 9                      Benzylpenicillin
# 10                             Cefaclor
# 11                           Cefadroxil
# 12                            Cefalexin
# 13                            Cefalotin
# 14                          Cefamandole
# 15                            Cefazolin
# 16                             Cefepime
# 17                             Cefepime
# 18                          Cefiderocol
# 19                             Cefixime
# 20                           Cefotaxime
# 21                            Cefoxitin
# 22                            Cefradine
# 23                  Ceftaroline fosamil
# 24                          Ceftazidime
# 25              Ceftazidime + Avibactam
# 26                         Ceftobiprole
# 27             Ceftolozane + Tazobactam
# 28                          Ceftriaxone
# 29                           Cefuroxime
# 30                      Chloramphenicol
# 31   Cilastatin + Imipenem + Relebactam
# 32                        Ciprofloxacin
# 33                        Ciprofloxacin
# 34                        Ciprofloxacin
# 35                       Clarithromycin
# 36                          Clindamycin
# 37                          Clindamycin
# 38                          Clindamycin
# 39                          Clindamycin
# 40                         Co-amoxiclav
# 41                       Co-trimoxazole
# 42                             Colistin
# 43                             Colistin
# 44                          Dalbavancin
# 45                           Daptomycin
# 46                         Delafloxacin
# 47                       Demeclocycline
# 48                            Doripenem
# 49                          Doxycycline
# 50                          Doxycycline
# 51                         Eravacycline
# 52                            Ertapenem
# 53                         Erythromycin
# 54                         Erythromycin
# 55                         Erythromycin
# 56                         Erythromycin
# 57                         Erythromycin
# 58                         Erythromycin
# 59                         Erythromycin
# 60                         Erythromycin
# 61                          Fidaxomicin
# 62                       Flucloxacillin
# 63                           Fosfomycin
# 64                           Fosfomycin
# 65                         Fusidic acid
# 66                         Fusidic acid
# 67                         Fusidic acid
# 68                           Gentamicin
# 69                           Gentamicin
# 70                Imipenem + Cilastatin
# 71                         Levofloxacin
# 72                         Levofloxacin
# 73                            Linezolid
# 74                          Lymecycline
# 75                            Meropenem
# 76              Meropenem + Vaborbactam
# 77                          Methenamine
# 78                        Metronidazole
# 79                          Minocycline
# 80                         Moxifloxacin
# 81                       Nalidixic Acid
# 82                             Neomycin
# 83                             Neomycin
# 84                             Neomycin
# 85                             Neomycin
# 86                             Neomycin
# 87                             Neomycin
# 88                             Neomycin
# 89                             Neomycin
# 90                             Neomycin
# 91                       Nitrofurantoin
# 92                          Norfloxacin
# 93                            Ofloxacin
# 94                          Oritavancin
# 95                      Oxytetracycline
# 96                      Oxytetracycline
# 97                      Oxytetracycline
# 98              Phenoxymethylpenicillin
# 99            Piperacillin + Tazobactam
# 100                       Pivmecillinam
# 101                       Pristinamycin
# 102           Procaine benzylpenicillin
# 103         Quinupristin + Dalfopristin
# 104                       Spectinomycin
# 105                          Spiramycin
# 106                        Streptomycin
# 107                        Sulfadiazine
# 108                        Sulfadiazine
# 109                        Sulfadiazine
# 110              Sulfamethoxypyridazine
# 111                       Sulfapyridine
# 112                           Tedizolid
# 113                         Teicoplanin
# 114                          Telavancin
# 115                          Temocillin
# 116                        Tetracycline
# 117                         Tigecycline
# 118                          Tinidazole
# 119                          Tobramycin
# 120                          Tobramycin
# 121                        Trimethoprim
# 122                        Trimethoprim
# 123                          Vancomycin
#
#                                            nm            id atc_route  \
# 0                          Amikacin liposomal  7.824210e+08       NaN
# 1                                    Amikacin  7.745340e+08       NaN
# 2                                 Amoxicillin  7.745860e+08       NaN
# 3                 Ampicillin + Flucloxacillin  7.745920e+08       NaN
# 4                                  Ampicillin  7.745900e+08       NaN
# 5                                Azithromycin  7.747220e+08       NaN
# 6                       Aztreonam + Avibactam  4.379671e+16       NaN
# 7                                   Aztreonam  7.747250e+08       NaN
# 8                 Benzathine benzylpenicillin  1.234764e+09       NaN
# 9                            Benzylpenicillin  7.748260e+08       NaN
# 10                                   Cefaclor  7.750860e+08       NaN
# 11                                 Cefadroxil  7.750870e+08       NaN
# 12                                  Cefalexin  7.750880e+08       NaN
# 13                                        NaN           NaN       NaN
# 14                                Cefamandole  7.750900e+08       NaN
# 15                                  Cefazolin  7.750920e+08       NaN
# 16                                   Cefepime  7.750950e+08       NaN
# 17                  Cefepime + Enmetazobactam  4.289421e+16       NaN
# 18                                Cefiderocol  8.302050e+08       NaN
# 19                                   Cefixime  7.750970e+08       NaN
# 20                                 Cefotaxime  7.751030e+08       NaN
# 21                                  Cefoxitin  7.751070e+08       NaN
# 22                                  Cefradine  7.751120e+08       NaN
# 23                        Ceftaroline fosamil  2.138731e+16       NaN
# 24                                Ceftazidime  7.751150e+08       NaN
# 25                    Ceftazidime + Avibactam  7.813000e+08       NaN
# 26                               Ceftobiprole  1.287090e+09       NaN
# 27                   Ceftolozane + Tazobactam  7.751190e+08       NaN
# 28                                Ceftriaxone  7.751200e+08       NaN
# 29                                 Cefuroxime  7.751210e+08       NaN
# 30                            Chloramphenicol  7.751600e+08       NaN
# 31         Cilastatin + Imipenem + Relebactam  7.890740e+08       NaN
# 32     Ciprofloxacin + Fluocinolone acetonide  3.587311e+16       NaN
# 33              Ciprofloxacin + Dexamethasone  7.752620e+08       NaN
# 34                              Ciprofloxacin  7.752610e+08       NaN
# 35                             Clarithromycin  7.752770e+08       NaN
# 36             Benzoyl peroxide + Clindamycin  7.748120e+08       NaN
# 37                                Clindamycin  7.752880e+08       NaN
# 38               Clindamycin + Hydrocortisone  2.220751e+16       NaN
# 39                    Clindamycin + Tretinoin  7.752890e+08       NaN
# 40                               Co-amoxiclav  7.745870e+08       NaN
# 41                             Co-trimoxazole  1.803751e+16       NaN
# 42                                   Colistin  7.753730e+08         O
# 43                                   Colistin  7.753730e+08         P
# 44                                Dalbavancin  7.754370e+08       NaN
# 45                                 Daptomycin  7.754510e+08       NaN
# 46                               Delafloxacin  7.754690e+08       NaN
# 47                             Demeclocycline  7.754760e+08       NaN
# 48                                  Doripenem  7.756890e+08       NaN
# 49                                Doxycycline  7.756980e+08       NaN
# 50     Betamethasone + Doxycycline + Nystatin  4.058881e+16       NaN
# 51                               Eravacycline  7.758070e+08       NaN
# 52                                  Ertapenem  7.758200e+08       NaN
# 53                Isotretinoin + Erythromycin  7.758230e+08       NaN
# 54            Benzoyl peroxide + Erythromycin  7.748130e+08       NaN
# 55               Erythromycin ethyl succinate  3.640851e+16       NaN
# 56                               Erythromycin  7.758220e+08       NaN
# 57                      Erythromycin stearate  3.640861e+16       NaN
# 58                   Tretinoin + Erythromycin  7.758250e+08       NaN
# 59                Erythromycin + Zinc acetate  7.758270e+08       NaN
# 60                  Erythromycin lactobionate  3.640951e+16       NaN
# 61                                Fidaxomicin  7.759610e+08       NaN
# 62                             Flucloxacillin  7.759790e+08       NaN
# 63                                 Fosfomycin  7.760410e+08         P
# 64                                 Fosfomycin  7.760410e+08         O
# 65               Betamethasone + Fusidic acid  7.748430e+08       NaN
# 66              Hydrocortisone + Fusidic acid  7.760590e+08       NaN
# 67                               Fusidic acid  7.760580e+08       NaN
# 68                                 Gentamicin  7.760940e+08       NaN
# 69                Gentamicin + Hydrocortisone  7.760950e+08       NaN
# 70                      Imipenem + Cilastatin  7.752450e+08       NaN
# 71                               Levofloxacin  7.765170e+08       NaN
# 72               Dexamethasone + Levofloxacin  1.286887e+09       NaN
# 73                                  Linezolid  7.765440e+08       NaN
# 74                                Lymecycline  7.765930e+08       NaN
# 75                                  Meropenem  7.766940e+08       NaN
# 76                    Meropenem + Vaborbactam  7.766950e+08       NaN
# 77                                Methenamine  7.767250e+08       NaN
# 78                              Metronidazole  7.767740e+08       NaN
# 79                                Minocycline  7.768000e+08         O
# 80                               Moxifloxacin  7.768310e+08       NaN
# 81                                        NaN           NaN       NaN
# 82           Clobetasol + Neomycin + Nystatin  7.752960e+08       NaN
# 83                      Neomycin + Gramicidin  7.761450e+08       NaN
# 84          Fluocinolone acetonide + Neomycin  2.263691e+16       NaN
# 85                   Neomycin + Triamcinolone  7.768900e+08       NaN
# 86                   Neomycin + Chlorhexidine  7.751700e+08       NaN
# 87                   Betamethasone + Neomycin  7.748440e+08       NaN
# 88                    Neomycin + Prednisolone  7.768890e+08       NaN
# 89                  Hydrocortisone + Neomycin  7.762540e+08       NaN
# 90                                   Neomycin  7.768850e+08       NaN
# 91                             Nitrofurantoin  7.769270e+08       NaN
# 92                                Norfloxacin  7.769430e+08       NaN
# 93                                  Ofloxacin  7.769730e+08       NaN
# 94                                Oritavancin  7.770010e+08       NaN
# 95           Oxytetracycline + Hydrocortisone  7.762570e+08       NaN
# 96   Clobetasone + Oxytetracycline + Nystatin  7.752990e+08       NaN
# 97                            Oxytetracycline  7.770350e+08       NaN
# 98                    Phenoxymethylpenicillin  7.771750e+08       NaN
# 99                  Piperacillin + Tazobactam  7.772120e+08       NaN
# 100                             Pivmecillinam  7.772270e+08       NaN
# 101                             Pristinamycin  1.625101e+16       NaN
# 102                 Procaine benzylpenicillin  1.234762e+09       NaN
# 103               Quinupristin + Dalfopristin  7.754390e+08       NaN
# 104                             Spectinomycin  7.776000e+08       NaN
# 105                                Spiramycin  7.776020e+08       NaN
# 106                              Streptomycin  7.776140e+08         P
# 107      Cerium nitrate + Sulfadiazine silver  4.277911e+16       NaN
# 108                       Sulfadiazine silver  8.640080e+08       NaN
# 109                              Sulfadiazine  7.775320e+08       NaN
# 110                    Sulfamethoxypyridazine  7.776430e+08       NaN
# 111                             Sulfapyridine  1.546581e+16       NaN
# 112                                 Tedizolid  7.776860e+08       NaN
# 113                               Teicoplanin  7.776910e+08       NaN
# 114                                Telavancin  7.776930e+08       NaN
# 115                                Temocillin  7.777000e+08       NaN
# 116                              Tetracycline  7.777300e+08       NaN
# 117                               Tigecycline  7.777690e+08       NaN
# 118                                Tinidazole  7.777750e+08       NaN
# 119                                Tobramycin  7.777910e+08       NaN
# 120                Dexamethasone + Tobramycin  7.755020e+08       NaN
# 121                              Trimethoprim  7.778580e+08       NaN
# 122                Polymyxin B + Trimethoprim  7.772470e+08       NaN
# 123                                Vancomycin  7.779140e+08       NaN
#
#     aware_2019 aware_2024
# 0        Watch      Watch
# 1        Watch      Watch
# 2       Access     Access
# 3       Access     Access
# 4       Access     Access
# 5        Watch      Watch
# 6      Reserve    Reserve
# 7      Reserve    Reserve
# 8       Access     Access
# 9       Access     Access
# 10       Watch      Watch
# 11       Watch     Access
# 12       Watch     Access
# 13       Watch     Access
# 14       Watch      Watch
# 15       Watch     Access
# 16       Watch      Watch
# 17       Watch      Watch
# 18     Reserve    Reserve
# 19       Watch      Watch
# 20       Watch      Watch
# 21       Watch      Watch
# 22       Watch     Access
# 23     Reserve    Reserve
# 24       Watch      Watch
# 25     Reserve    Reserve
# 26     Reserve    Reserve
# 27     Reserve    Reserve
# 28       Watch      Watch
# 29       Watch      Watch
# 30       Watch      Watch
# 31     Reserve    Reserve
# 32       Watch      Watch
# 33       Watch      Watch
# 34       Watch      Watch
# 35       Watch      Watch
# 36       Watch      Watch
# 37       Watch      Watch
# 38       Watch      Watch
# 39       Watch      Watch
# 40       Watch      Watch
# 41      Access     Access
# 42     Reserve    Reserve
# 43     Reserve    Reserve
# 44     Reserve    Reserve
# 45     Reserve    Reserve
# 46       Watch      Watch
# 47       Watch      Other
# 48     Reserve    Reserve
# 49      Access     Access
# 50      Access     Access
# 51     Reserve    Reserve
# 52     Reserve    Reserve
# 53       Watch      Watch
# 54       Watch      Watch
# 55       Watch      Watch
# 56       Watch      Watch
# 57       Watch      Watch
# 58       Watch      Watch
# 59       Watch      Watch
# 60       Watch      Watch
# 61       Watch      Watch
# 62      Access     Access
# 63     Reserve    Reserve
# 64      Access     Access
# 65      Access      Watch
# 66      Access      Watch
# 67      Access      Watch
# 68      Access     Access
# 69      Access     Access
# 70     Reserve    Reserve
# 71       Watch      Watch
# 72       Watch      Watch
# 73     Reserve    Reserve
# 74       Watch      Watch
# 75     Reserve    Reserve
# 76     Reserve    Reserve
# 77       Other      Other
# 78      Access     Access
# 79       Watch      Watch
# 80       Watch      Watch
# 81       Other      Other
# 82       Watch      Watch
# 83       Watch      Watch
# 84       Watch      Watch
# 85       Watch      Watch
# 86       Watch      Watch
# 87       Watch      Watch
# 88       Watch      Watch
# 89       Watch      Watch
# 90       Watch      Watch
# 91      Access     Access
# 92       Watch      Watch
# 93       Watch      Watch
# 94     Reserve    Reserve
# 95       Watch      Watch
# 96       Watch      Watch
# 97       Watch      Watch
# 98      Access     Access
# 99       Watch      Watch
# 100     Access     Access
# 101      Watch      Other
# 102     Access     Access
# 103    Reserve    Reserve
# 104      Other      Other
# 105      Other      Other
# 106      Other      Other
# 107      Other      Other
# 108      Other      Other
# 109      Other      Other
# 110      Other      Other
# 111      Other      Other
# 112    Reserve    Reserve
# 113      Watch      Watch
# 114    Reserve    Reserve
# 115      Watch      Watch
# 116     Access     Access
# 117    Reserve    Reserve
# 118      Other     Access
# 119      Watch      Watch
# 120      Watch      Watch
# 121     Access     Access
# 122     Access     Access
# 123      Watch      Watch

# %% [markdown]
# ### Bringing in VMPs

# %% [markdown]
# Now that we have a list of dm+d compatible VTMs, we can bring in matching VMPs.

# %%
sql = f"""
WITH matched_vtms AS ( -- This query does the fuzzy matching of Antibiotic name to VTM name
  SELECT  
    aware.Antibiotic,
    aware.atc_route,
    aware.aware_2019,
    aware.aware_2024,
    vtm.nm,
    vtm.id,
    CASE
      WHEN aware.Antibiotic = vtm.nm THEN 'DIRECT'
      ELSE 'ASSUMED'
    END AS match_type
  FROM `ebmdatalab.chris.aware_list` aware
  LEFT JOIN `ebmdatalab.dmd.vtm` vtm 
    ON vtm.nm LIKE CONCAT('%', aware.Antibiotic, '%')
  WHERE vtm.invalid IS NOT TRUE
),

manual_exceptions AS ( -- This is a list of manual exceptions used when recluding assumed matches
  SELECT 'Ampicillin' AS Antibiotic, 'Ampicillin + Flucloxacillin' AS nm
  -- Add more rows here as needed
),

duplicate_vtms AS ( -- This produces a list of duplicate rows where a direct match already exists
  SELECT *
  FROM matched_vtms
  WHERE nm IN (
    SELECT nm
    FROM matched_vtms
    WHERE atc_route IS NULL
    GROUP BY nm
    HAVING COUNT(*) > 1
  )
  AND match_type = 'ASSUMED'
  AND NOT EXISTS (
    SELECT 1
    FROM manual_exceptions e
    WHERE e.Antibiotic = matched_vtms.Antibiotic AND e.nm = matched_vtms.nm
  )
),

vmp_with_route AS (
  SELECT DISTINCT
    vmp.id AS id,
    vmp.vtm AS vtm,
    vmp.nm AS nm,
    COALESCE(sroute.route, routelookup.who_route) AS vmp_atc_route
  FROM `ebmdatalab.dmd.vmp` vmp
  LEFT JOIN dmd.ont ont ON vmp.id = ont.vmp
  LEFT JOIN dmd.ontformroute ofr ON ont.form = ofr.cd
  LEFT JOIN chris.vmp_single_route_identifier sroute ON vmp.id = sroute.vmp_id
  LEFT JOIN `scmd_dmd_views.dmd_to_atc_route` routelookup ON ofr.descr = routelookup.dmd_ofr
)

SELECT DISTINCT
  matched_vtms.Antibiotic,
  matched_vtms.nm as vtm_nm,
  matched_vtms.id as vtm_id,
  vmp.nm as vmp_nm,
  vmp.id as vmp_id,
  vmp.vmp_atc_route,
  matched_vtms.atc_route,
  matched_vtms.aware_2019,
  matched_vtms.aware_2024
FROM matched_vtms
LEFT JOIN vmp_with_route vmp
  ON matched_vtms.id = vmp.vtm
  AND (
    matched_vtms.atc_route IS NULL
    OR matched_vtms.atc_route = vmp.vmp_atc_route
  )
WHERE NOT EXISTS ( -- removes the duplicates identified above
  SELECT 1
  FROM duplicate_vtms
  WHERE matched_vtms.Antibiotic = duplicate_vtms.Antibiotic AND matched_vtms.nm = duplicate_vtms.nm
)
ORDER BY matched_vtms.Antibiotic ASC;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vmps_matched.csv')

# Use the cached_read function from the bq library to run the query.
vmps_matched = bq.cached_read(sql, csv_path=csv_path)

vmps_matched
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████|
#      Antibiotic              vtm_nm     vtm_id  \
# 0      Amikacin  Amikacin liposomal  782421008
# 1      Amikacin            Amikacin  774534000
# 2      Amikacin            Amikacin  774534000
# 3      Amikacin            Amikacin  774534000
# 4      Amikacin            Amikacin  774534000
# ..          ...                 ...        ...
# 703  Vancomycin          Vancomycin  777914002
# 704  Vancomycin          Vancomycin  777914002
# 705  Vancomycin          Vancomycin  777914002
# 706  Vancomycin          Vancomycin  777914002
# 707  Vancomycin          Vancomycin  777914002
#
#                                                 vmp_nm             vmp_id  \
# 0    Amikacin liposomal 590mg nebuliser dispersion ...  39601711000001109
# 1    Amikacin 500mg/2ml solution for injection ampo...  44422511000001103
# 2    Amikacin 25mg/5ml solution for injection ampoules  44007311000001107
# 3    Amikacin 500mg/100ml infusion polyethylene bot...  41823511000001108
# 4    Amikacin 400micrograms/0.1ml intravitreal inje...  38244211000001108
# ..                                                 ...                ...
# 703                Vancomycin 62.5mg/5ml oral solution  13455811000001106
# 704                 Vancomycin 125mg/5ml oral solution  15453011000001107
# 705               Vancomycin 125mg/5ml oral suspension  15453111000001108
# 706                            Vancomycin 5% eye drops  21407511000001100
# 707                          Vancomycin 1.4% eye drops  22103111000001101
#
#       vmp_atc_route atc_route aware_2019 aware_2024
# 0    Inhal.solution      None      Watch      Watch
# 1                 P      None      Watch      Watch
# 2              None      None      Watch      Watch
# 3                 P      None      Watch      Watch
# 4              None      None      Watch      Watch
# ..              ...       ...        ...        ...
# 703               O      None      Watch      Watch
# 704               O      None      Watch      Watch
# 705               O      None      Watch      Watch
# 706            None      None      Watch      Watch
# 707            None      None      Watch      Watch
#
# [708 rows x 9 columns]

# %% [markdown]
# Inspecting this list we can see a number of non-systemic antibiotics which are not considered as part of the AWaRe classification - e.g. eye drops, ointments etc. We can remove these by filtering out when selecting VMPs.

# %%
sql = f"""
WITH matched_vtms AS ( -- This query does the fuzzy matching of Antibiotic name to VTM name
  SELECT  
    aware.Antibiotic,
    aware.atc_route,
    aware.aware_2019,
    aware.aware_2024,
    vtm.nm,
    vtm.id,
    CASE
      WHEN aware.Antibiotic = vtm.nm THEN 'DIRECT'
      ELSE 'ASSUMED'
    END AS match_type
  FROM `ebmdatalab.chris.aware_list` aware
  LEFT JOIN `ebmdatalab.dmd.vtm` vtm 
    ON vtm.nm LIKE CONCAT('%', aware.Antibiotic, '%')
  WHERE vtm.invalid IS NOT TRUE
),

manual_exceptions AS ( -- This is a list of manual exceptions used when recluding assumed matches
  SELECT 'Ampicillin' AS Antibiotic, 'Ampicillin + Flucloxacillin' AS nm
  -- Add more rows here as needed
),

duplicate_vtms AS ( -- This produces a list of duplicate rows where a direct match already exists
  SELECT *
  FROM matched_vtms
  WHERE nm IN (
    SELECT nm
    FROM matched_vtms
    WHERE atc_route IS NULL
    GROUP BY nm
    HAVING COUNT(*) > 1
  )
  AND match_type = 'ASSUMED'
  AND NOT EXISTS (
    SELECT 1
    FROM manual_exceptions e
    WHERE e.Antibiotic = matched_vtms.Antibiotic AND e.nm = matched_vtms.nm
  )
),

vmp_with_route AS (
  SELECT DISTINCT
    vmp.id AS id,
    vmp.vtm AS vtm,
    vmp.nm AS nm,
    COALESCE(sroute.route, routelookup.who_route) AS vmp_atc_route
  FROM `ebmdatalab.dmd.vmp` vmp
  LEFT JOIN dmd.ont ont ON vmp.id = ont.vmp
  LEFT JOIN dmd.ontformroute ofr ON ont.form = ofr.cd
  LEFT JOIN chris.vmp_single_route_identifier sroute ON vmp.id = sroute.vmp_id
  LEFT JOIN `scmd_dmd_views.dmd_to_atc_route` routelookup ON ofr.descr = routelookup.dmd_ofr
  WHERE ofr.descr NOT LIKE '%.auricular'
  AND ofr.descr NOT LIKE '%.cutaneous'
  AND ofr.descr NOT LIKE '%.ophthalmic'
  AND ofr.descr NOT LIKE '%.oromucosal'
  AND ofr.descr NOT LIKE '%.intralesional'
  AND ofr.descr NOT LIKE '%.nasal'
)

SELECT DISTINCT
  matched_vtms.Antibiotic,
  matched_vtms.nm as vtm_nm,
  matched_vtms.id as vtm_id,
  vmp.nm as vmp_nm,
  vmp.id as vmp_id,
  vmp.vmp_atc_route,
  matched_vtms.atc_route,
  matched_vtms.aware_2019,
  matched_vtms.aware_2024
FROM matched_vtms
LEFT JOIN vmp_with_route vmp
  ON matched_vtms.id = vmp.vtm
  AND (
    matched_vtms.atc_route IS NULL
    OR matched_vtms.atc_route = vmp.vmp_atc_route
  )
WHERE NOT EXISTS ( -- removes the duplicates identified above
  SELECT 1
  FROM duplicate_vtms
  WHERE matched_vtms.Antibiotic = duplicate_vtms.Antibiotic AND matched_vtms.nm = duplicate_vtms.nm
) AND vmp.id IS NOT NULL
ORDER BY matched_vtms.Antibiotic ASC;
"""

# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vmps_matched.csv')

# Use the cached_read function from the bq library to run the query.
vmps_matched = bq.cached_read(sql, csv_path=csv_path)

with pd.option_context('display.max_rows', None):
    display(vmps_matched)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████|
#                              Antibiotic                              vtm_nm  \
# 0                              Amikacin                  Amikacin liposomal
# 1                              Amikacin                            Amikacin
# 2                              Amikacin                            Amikacin
# 3                              Amikacin                            Amikacin
# 4                              Amikacin                            Amikacin
# 5                              Amikacin                            Amikacin
# 6                              Amikacin                            Amikacin
# 7                              Amikacin                            Amikacin
# 8                              Amikacin                            Amikacin
# 9                           Amoxicillin                         Amoxicillin
# 10                          Amoxicillin                         Amoxicillin
# 11                          Amoxicillin                         Amoxicillin
# 12                          Amoxicillin                         Amoxicillin
# 13                          Amoxicillin                         Amoxicillin
# 14                          Amoxicillin                         Amoxicillin
# 15                          Amoxicillin                         Amoxicillin
# 16                          Amoxicillin                         Amoxicillin
# 17                          Amoxicillin                         Amoxicillin
# 18                          Amoxicillin                         Amoxicillin
# 288                          Fosfomycin                          Fosfomycin
# 289                          Fosfomycin                          Fosfomycin
# 290                          Fosfomycin                          Fosfomycin
# 291                          Fosfomycin                          Fosfomycin
# 292                          Fosfomycin                          Fosfomycin
# 293                        Fusidic acid                        Fusidic acid
# 294                          Gentamicin                          Gentamicin
# 295                          Gentamicin                          Gentamicin
# 296                          Gentamicin                          Gentamicin
# 297                          Gentamicin                          Gentamicin
# 298                          Gentamicin                          Gentamicin
# 299                          Gentamicin                          Gentamicin
# 300                          Gentamicin                          Gentamicin
# 301                          Gentamicin                          Gentamicin
# 302                          Gentamicin                          Gentamicin
# 303                          Gentamicin                          Gentamicin
# 304                          Gentamicin                          Gentamicin
# 305                          Gentamicin                          Gentamicin
# 306                          Gentamicin                          Gentamicin
# 307                          Gentamicin                          Gentamicin
# 308                          Gentamicin                          Gentamicin
# 309                          Gentamicin                          Gentamicin
# 310                          Gentamicin                          Gentamicin
# 311                          Gentamicin                          Gentamicin
# 312                          Gentamicin                          Gentamicin
# 313                          Gentamicin                          Gentamicin
# 314                          Gentamicin                          Gentamicin
# 315                          Gentamicin                          Gentamicin
# 316                          Gentamicin                          Gentamicin
# 317                          Gentamicin                          Gentamicin
# 318                          Gentamicin                          Gentamicin
# 319                          Gentamicin                          Gentamicin
# 320                          Gentamicin                          Gentamicin
# 321               Imipenem + Cilastatin               Imipenem + Cilastatin
# 322               Imipenem + Cilastatin               Imipenem + Cilastatin
# 323                        Levofloxacin                        Levofloxacin
# 324                        Levofloxacin                        Levofloxacin
# 325                        Levofloxacin                        Levofloxacin
# 326                        Levofloxacin                        Levofloxacin
# 327                        Levofloxacin                        Levofloxacin
# 328                        Levofloxacin                        Levofloxacin
# 329                        Levofloxacin                        Levofloxacin
# 330                        Levofloxacin                        Levofloxacin
# 331                           Linezolid                           Linezolid
# 332                           Linezolid                           Linezolid
# 333                           Linezolid                           Linezolid
# 334                           Linezolid                           Linezolid
# 335                         Lymecycline                         Lymecycline
# 336                           Meropenem                           Meropenem
# 337                           Meropenem                           Meropenem
# 338                           Meropenem                           Meropenem
# 339                           Meropenem                           Meropenem
# 340                           Meropenem                           Meropenem
# 341             Meropenem + Vaborbactam             Meropenem + Vaborbactam
# 342                         Methenamine                         Methenamine
# 343                       Metronidazole                       Metronidazole
# 344                       Metronidazole                       Metronidazole
# 345                       Metronidazole                       Metronidazole
# 346                       Metronidazole                       Metronidazole
# 347                       Metronidazole                       Metronidazole
# 348                       Metronidazole                       Metronidazole
# 349                       Metronidazole                       Metronidazole
# 350                       Metronidazole                       Metronidazole
# 351                       Metronidazole                       Metronidazole
# 352                       Metronidazole                       Metronidazole
# 353                       Metronidazole                       Metronidazole
# 354                       Metronidazole                       Metronidazole
# 355                       Metronidazole                       Metronidazole
# 356                       Metronidazole                       Metronidazole
# 357                       Metronidazole                       Metronidazole
# 358                       Metronidazole                       Metronidazole
# 359                       Metronidazole                       Metronidazole
# 360                       Metronidazole                       Metronidazole
# 361                         Minocycline                         Minocycline
# 549                          Tobramycin                          Tobramycin
# 550                          Tobramycin                          Tobramycin
# 551                          Tobramycin                          Tobramycin
# 552                          Tobramycin                          Tobramycin
# 553                        Trimethoprim                        Trimethoprim
# 554                        Trimethoprim                        Trimethoprim
# 555                        Trimethoprim                        Trimethoprim
# 556                        Trimethoprim                        Trimethoprim
# 557                        Trimethoprim                        Trimethoprim
# 558                        Trimethoprim                        Trimethoprim
# 559                        Trimethoprim                        Trimethoprim
# 560                        Trimethoprim                        Trimethoprim
# 561                        Trimethoprim                        Trimethoprim
# 562                        Trimethoprim                        Trimethoprim
# 563                        Trimethoprim                        Trimethoprim
# 564                        Trimethoprim                        Trimethoprim
# 565                          Vancomycin                          Vancomycin
# 566                          Vancomycin                          Vancomycin
# 567                          Vancomycin                          Vancomycin
# 568                          Vancomycin                          Vancomycin
# 569                          Vancomycin                          Vancomycin
# 570                          Vancomycin                          Vancomycin
# 571                          Vancomycin                          Vancomycin
# 572                          Vancomycin                          Vancomycin
# 573                          Vancomycin                          Vancomycin
# 574                          Vancomycin                          Vancomycin
# 575                          Vancomycin                          Vancomycin
# 576                          Vancomycin                          Vancomycin
# 577                          Vancomycin                          Vancomycin
# 578                          Vancomycin                          Vancomycin
# 579                          Vancomycin                          Vancomycin
# 580                          Vancomycin                          Vancomycin
# 581                          Vancomycin                          Vancomycin
# 582                          Vancomycin                          Vancomycin
# 583                          Vancomycin                          Vancomycin
# 584                          Vancomycin                          Vancomycin
# 585                          Vancomycin                          Vancomycin
# 586                          Vancomycin                          Vancomycin
# 587                          Vancomycin                          Vancomycin
# 588                          Vancomycin                          Vancomycin
# 589                          Vancomycin                          Vancomycin
# 590                          Vancomycin                          Vancomycin
# 591                          Vancomycin                          Vancomycin
# 592                          Vancomycin                          Vancomycin
# 593                          Vancomycin                          Vancomycin
# 594                          Vancomycin                          Vancomycin
# 595                          Vancomycin                          Vancomycin
#
#                 vtm_id                                             vmp_nm  \
# 0            782421008  Amikacin liposomal 590mg nebuliser dispersion ...
# 1            774534000  Amikacin 500mg/2ml solution for injection ampo...
# 2            774534000  Amikacin 25mg/5ml solution for injection ampoules
# 3            774534000  Amikacin 500mg/100ml infusion polyethylene bot...
# 4            774534000  Amikacin 400micrograms/0.1ml intravitreal inje...
# 5            774534000     Amikacin 25mg/5ml solution for injection vials
# 6            774534000  Amikacin 25mg/5ml solution for injection pre-f...
# 7            774534000    Amikacin 500mg/2ml solution for injection vials
# ...
# 377  12302011000001102               O      None      Watch      Watch
# 378  41953111000001108               O      None     Access     Access
# 379  41952811000001109               O      None     Access     Access
# 380  41953211000001102               O      None     Access     Access
# 381  41952911000001104               O      None     Access     Access
# 382  39108511000001108               O      None     Access     Access
# 383  36565611000001103               O      None     Access     Access
# 384  12862911000001101               O      None     Access     Access
# 385  12862811000001106               O      None     Access     Access
# 386  12863111000001105               O      None     Access     Access
# 387  12863011000001109               O      None     Access     Access
# 388  12863311000001107               O      None     Access     Access
# 389  12863211000001104               O      None     Access     Access
# 390  12863511000001101               O      None     Access     Access
# 391  12863411000001100               O      None     Access     Access
# 392  12863711000001106               O      None     Access     Access
# 393  12863611000001102               O      None     Access     Access
# 394  12863911000001108               O      None     Access     Access
# 395  12863811000001103               O      None     Access     Access
# 396  12864111000001107               O      None     Access     Access
# 397  12864011000001106               O      None     Access     Access
# 398  12864311000001109               O      None     Access     Access
# 399  12864211000001101               O      None     Access     Access
# 400  12864511000001103               O      None     Access     Access
# 401  12864411000001102               O      None     Access     Access
# 402  12864711000001108               O      None     Access     Access
# 403  12864611000001104               O      None     Access     Access
# 404  12864911000001105               O      None     Access     Access
# 405  12864811000001100               O      None     Access     Access
# 406  12894011000001108               O      None     Access     Access
# 407  12893811000001100               O      None     Access     Access
# 408  12894211000001103               O      None     Access     Access
# 409  12894111000001109               O      None     Access     Access
# 410  12894511000001100               O      None     Access     Access
# 411  12894311000001106               O      None     Access     Access
# 412  12894711000001105               O      None     Access     Access
# 413  12894611000001101               O      None     Access     Access
# 414  12894811000001102               O      None     Access     Access
# 415  12895111000001108               O      None     Access     Access
# 416  12904111000001103               O      None     Access     Access
# 417  12904811000001105               O      None     Access     Access
# 418  12904311000001101               O      None     Access     Access
# 419  12904211000001109               O      None     Access     Access
# 420  12904511000001107               O      None     Access     Access
# 421  12904411000001108               O      None     Access     Access
# 422  12904711000001102               O      None     Access     Access
# 423  12904611000001106               O      None     Access     Access
# 424  41953011000001107               O      None     Access     Access
# 425  12904911000001100               O      None     Access     Access
# 426  12905111000001104               O      None     Access     Access
# 427  12905011000001100               O      None     Access     Access
# 428  12934011000001109               O      None     Access     Access
# 429  12933911000001106               O      None     Access     Access
# 430  12934211000001104               O      None     Access     Access
# 431  12934111000001105               O      None     Access     Access
# 432  12934411000001100               O      None     Access     Access
# 433  12934311000001107               O      None     Access     Access
# 434  12934611000001102               O      None     Access     Access
# 435  12934511000001101               O      None     Access     Access
# 436  12934811000001103               O      None     Access     Access
# 437  12934711000001106               O      None     Access     Access
# 438  12935011000001108               O      None     Access     Access
# 439  12934911000001108               O      None     Access     Access
# 440  12935211000001103               O      None     Access     Access
# 441  12935111000001109               O      None     Access     Access
# 442  12935411000001104               O      None     Access     Access
# 443  12935311000001106               O      None     Access     Access
# 444  12935611000001101               O      None     Access     Access
# 445  12935511000001100               O      None     Access     Access
# 446  12935811000001102               O      None     Access     Access
# 447  12935711000001105               O      None     Access     Access
# 448  12936011000001104               O      None     Access     Access
# 449  12935911000001107               O      None     Access     Access
# 450  12936211000001109               O      None     Access     Access
# 451  12936111000001103               O      None     Access     Access
# 452  12936411000001108               O      None     Access     Access
# 453  12936311000001101               O      None     Access     Access
# 454  12936611000001106               O      None     Access     Access
# 455  12936511000001107               O      None     Access     Access
# 456  12936811000001105               O      None     Access     Access
# 457  12936711000001102               O      None     Access     Access
# 458  12937011000001101               O      None     Access     Access
# 459  12936911000001100               O      None     Access     Access
# 460  12937211000001106               O      None     Access     Access
# 461  12937111000001100               O      None     Access     Access
# 462  12937411000001105               O      None     Access     Access
